# %% [markdown]
# This notebook addresses a crucial challenge encountered with our collaborator's data: many documents were initially associated with incorrect countries. To tackle this, we developed this notebook as an approach to obtain more accurately linked documents for a given country and event.
#
# Our process begins by defining a specific event through a chosen time period and country. A core part of our strategy involves using an Large Language Model (LLM) to generate a thematic description, which is inferred from the collective titles of the majority of documents initially gathered for that period and country. This LLM-provided theme then guides a subsequent manual filtering step, allowing us to identify and remove documents that seem irrelevant to the overall theme. The aim of this selective process is to refine the dataset and ensure that we have a collection of documents genuinely associated with the intended country and event. While this method is still under development and refinement, it represents our current best effort to improve data quality.

# %% [markdown]
# # Read Data

# %%
import os
import json 
import pandas as pd 
full_data = pd.read_excel("./Results/Sources/fulldata_scraped.xlsx") 
openaikey = ""

# %%
len(full_data['source_domain'].unique())
# Out:
# 142

# %%
vc = full_data['source_domain'].value_counts()

# Display 50 rows at a time
for i in range(0, len(vc), 50):
    print(vc.iloc[i:i+50].to_string())
# Out:
# source_domain
# reliefweb.int             22483
# allafrica.com              1828
# theguardian.com            1589
# radiotamazuj.org            971
# news.un.org                 969
# independent.co.uk           922
# globalsecurity.org          789
# abcnews.go.com              786
# aljazeera.com               781
# hrw.org                     762
# voanews.com                 755
# jamaica-gleaner.com         655
# tribune.com.pk              602
# apnews.com                  528
# dawn.com                    492
# darfur24.com                491
# english.news.cn             485
# dw.com                      485
# edition.cnn.com             483
# naharnet.com                456
# dailysabah.com              453
# preventionweb.net           440
# naharnet.com:443            432
# thedailystar.net            428
# jamaicaobserver.com         428
# aa.com.tr                   403
# al-monitor.com              375
# middleeastmonitor.com       365
# mb.com.ph                   359
# bbc.com                     321
# euronews.com                303
# rappler.com                 284
# the-star.co.ke              279
# hurriyetdailynews.com       265
# eyeradio.org                259
# premiumtimesng.com          253
# philstar.com                247
# dabangasudan.org            243
# middleeasteye.net           229
# bangkokpost.com             228
# thediplomat.com             224
# standardmedia.co.ke         218
# straitstimes.com            210
# thenewhumanitarian.org      182
# unocha.org                  180
# africanews.com              157
# cbc.bb                      152
# vietnamnews.vn              150
# barbadostoday.bb            142
# newsday.co.zw               138
# source_domain
# afghanistannews.net                               138
# wfp.org                                           131
# pakobserver.net                                   126
# rferl.org                                         121
# nytimes.com                                       114
# grist.org                                         108
# thejakartapost.com                                103
# pakistantoday.com.pk                              102
# vanguardngr.com                                   101
# albawaba.com                                      101
# channelnewsasia.com                               100
# khaama.com                                         91
# kyivpost.com                                       91
# en.antaranews.com                                  88
# who.int                                            84
# unhcr.org                                          84
# irrawaddy.com                                      83
# thevoiceslu.com                                    75
# malaymail.com                                      73
# khaosodenglish.com                                 71
# care.org                                           71
# searchlight.vc                                     71
# en.tempo.co                                        70
# iom.int                                            69
# unicef.org                                         61
# nowgrenada.com                                     61
# fao.org                                            61
# civil-protection-humanitarian-aid.ec.europa.eu     61
# msf.org                                            60
# kelownacapnews.com                                 53
# commission.europa.eu                               49
# amnesty.org.au                                     48
# euromedmonitor.org                                 47
# guardian.ng                                        46
# unfpa.org                                          46
# foreignaffairs.com                                 44
# propublica.org                                     43
# bnionline.net                                      41
# zimbabwesituation.com                              41
# bulatlat.com                                       40
# understandingwar.org                               38
# france24.com                                       37
# icrc.org                                           36
# caymannewsservice.com                              32
# ec.europa.eu                                       31
# bulawayo24.com                                     29
# lemonde.fr                                         27
# opm.gov.jm                                         24
# rfi.fr                                             22
# crisisgroup.org                                    20
# source_domain
# bursa.ro                              17
# cfr.org                               16
# amnesty.org                           16
# theonlinecitizen.com                  16
# chinadaily.com.cn                     15
# gisbarbados.gov.bb                    15
# rfa.org                               15
# bianet.org                            14
# unicef.org.au                         13
# altaghyeer.info                       13
# thethaiger.com                        12
# pajhwok.com                           11
# radiojamaicanewsonline.com            10
# arabnews.com                           8
# english.enabbaladi.net                 8
# pna.gov.ph                             8
# worldbank.org                          7
# hungarytoday.hu                        7
# benarnews.org                          7
# dailynewshungary.com                   7
# e.vnexpress.net                        5
# turkishminute.com                      5
# jakartaglobe.id                        5
# newafricanmagazine.com                 4
# malaysiakini.com                       3
# warsawvoice.pl                         3
# reuters.com                            3
# afro.who.int                           3
# libyaobserver.ly                       3
# zimeye.net                             3
# themalaysianinsight.com                3
# kyivindependent.com                    3
# caymancompass.com                      2
# ukrinform.net                          2
# tnx.africa                             1
# pravda.com.ua                          1
# cyprus.representation.ec.europa.eu     1
# stvincenttimes.com                     1
# undrr.org                              1
# sudantribune.com                       1
# zn.ua                                  1
# radiookapi.net                         1

# %%
len(vc)
# Out:
# 142

# %% [markdown]
# # Select data

# %% [markdown]
# ## Prepare dataframe

# %%
import ast 
import numpy as np

full_data.head()
full_data['publish_week'] = full_data['publish_date'].apply(lambda x: f"Week {x.isocalendar().week} {x.year}")
full_data['publish_month']=full_data['publish_date'].dt.strftime('%B %Y')



full_data['country'] = full_data['country'].apply(ast.literal_eval)
full_data = full_data[full_data['country'].apply(len) <=5]
full_data= full_data.explode('country').reset_index(drop=True)

countries = np.unique(full_data['country'])


ndocs_dict = full_data.groupby(['country', 'publish_week']).size().to_dict()
ndocs_dict = dict(sorted(ndocs_dict.items(), key=lambda item: item[1], reverse=True))

# %%
full_data['country'].value_counts()
# Out:
# United States            7701
# Palestinian Territory    4586
# Israel                   3420
# Sudan                    3169
# Mexico                   1885
#                          ...
# Gibraltar                   1
# Andorra                     1
# Faroe Islands               1
# Mercosur                    1
# Christmas Island            1
# Name: country, Length: 251, dtype: int64

# %%
ndocs_dict
# Out:
# {('United States', 'Week 39 2024'): 490,
#  ('United States', 'Week 40 2024'): 424,
#  ('United States', 'Week 41 2024'): 413,
#  ('United States', 'Week 32 2024'): 382,
#  ('United States', 'Week 30 2024'): 379,
#  ('United States', 'Week 37 2024'): 372,
#  ('United States', 'Week 31 2024'): 358,
#  ('Palestinian Territory', 'Week 35 2024'): 331,
#  ('United States', 'Week 35 2024'): 315,
#  ('United States', 'Week 25 2024'): 313,
#  ('United States', 'Week 36 2024'): 312,
#  ('United States', 'Week 38 2024'): 303,
#  ('United States', 'Week 19 2024'): 302,
#  ('United States', 'Week 21 2024'): 294,
#  ('United States', 'Week 34 2024'): 294,
#  ('United States', 'Week 23 2024'): 291,
#  ('United States', 'Week 28 2024'): 291,
#  ('United States', 'Week 33 2024'): 281,
#  ('United States', 'Week 22 2024'): 278,
#  ('United States', 'Week 24 2024'): 277,
#  ('United States', 'Week 27 2024'): 266,
#  ('United States', 'Week 29 2024'): 266,
#  ('Palestinian Territory', 'Week 19 2024'): 261,
#  ('United States', 'Week 26 2024'): 257,
#  ('Palestinian Territory', 'Week 41 2024'): 254,
#  ('Israel', 'Week 35 2024'): 243,
#  ('Lebanon', 'Week 40 2024'): 242,
#  ('United States', 'Week 20 2024'): 232,
#  ('Sudan', 'Week 31 2024'): 224,
#  ('Palestinian Territory', 'Week 36 2024'): 222,
#  ('Palestinian Territory', 'Week 34 2024'): 219,
#  ('Israel', 'Week 19 2024'): 215,
#  ('Israel', 'Week 41 2024'): 212,
#  ('Palestinian Territory', 'Week 28 2024'): 201,
#  ('Lebanon', 'Week 39 2024'): 200,
#  ('Palestinian Territory', 'Week 24 2024'): 198,
#  ('Sudan', 'Week 35 2024'): 198,
#  ('Palestinian Territory', 'Week 31 2024'): 197,
#  ('Lebanon', 'Week 41 2024'): 196,
#  ('Palestinian Territory', 'Week 29 2024'): 190,
#  ('Palestinian Territory', 'Week 39 2024'): 188,
#  ('Palestinian Territory', 'Week 20 2024'): 184,
#  ('Palestinian Territory', 'Week 40 2024'): 178,
#  ('Sudan', 'Week 39 2024'): 178,
#  ('Palestinian Territory', 'Week 37 2024'): 177,
#  ('United Kingdom', 'Week 32 2024'): 173,
#  ('Palestinian Territory', 'Week 32 2024'): 171,
#  ('Philippines', 'Week 30 2024'): 171,
#  ('Sudan', 'Week 34 2024'): 169,
#  ('Palestinian Territory', 'Week 22 2024'): 168,
#  ('Palestinian Territory', 'Week 33 2024'): 164,
#  ('Israel', 'Week 36 2024'): 163,
#  ('Palestinian Territory', 'Week 30 2024'): 163,
#  ('Palestinian Territory', 'Week 23 2024'): 162,
#  ('Palestinian Territory', 'Week 25 2024'): 162,
#  ('Nigeria', 'Week 37 2024'): 160,
#  ('United States', 'Week 42 2024'): 158,
#  ('Israel', 'Week 40 2024'): 157,
#  ('Palestinian Territory', 'Week 27 2024'): 155,
#  ('Israel', 'Week 39 2024'): 153,
#  ('United States', 'Week 18 2024'): 153,
#  ('Israel', 'Week 22 2024'): 151,
#  ('Sudan', 'Week 36 2024'): 151,
#  ('India', 'Week 31 2024'): 149,
#  ('Israel', 'Week 28 2024'): 149,
#  ('Sudan', 'Week 37 2024'): 149,
#  ('Sudan', 'Week 33 2024'): 147,
#  ('Israel', 'Week 20 2024'): 146,
#  ('Palestinian Territory', 'Week 21 2024'): 146,
#  ('Palestinian Territory', 'Week 38 2024'): 145,
#  ('Sudan', 'Week 24 2024'): 145,
#  ('Sudan', 'Week 32 2024'): 142,
#  ('Mexico', 'Week 39 2024'): 140,
#  ('Mexico', 'Week 40 2024'): 140,
#  ('Israel', 'Week 31 2024'): 138,
#  ('Israel', 'Week 34 2024'): 138,
#  ('Israel', 'Week 29 2024'): 137,
#  ('Sudan', 'Week 40 2024'): 136,
#  ('Sudan', 'Week 41 2024'): 136,
#  ('Israel', 'Week 24 2024'): 134,
#  ('Sudan', 'Week 26 2024'): 132,
#  ('Israel', 'Week 25 2024'): 131,
#  ('United Kingdom', 'Week 41 2024'): 131,
#  ('South Sudan', 'Week 33 2024'): 130,
#  ('Sudan', 'Week 25 2024'): 130,
#  ('Palestinian Territory', 'Week 26 2024'): 129,
#  ('Sudan', 'Week 29 2024'): 128,
#  ('China', 'Week 37 2024'): 127,
#  ('Palestinian Territory', 'Week 42 2024'): 126,
#  ('Israel', 'Week 23 2024'): 125,
#  ('Vietnam', 'Week 37 2024'): 125,
#  ('India', 'Week 34 2024'): 124,
#  ('Sudan', 'Week 38 2024'): 124,
#  ('Mexico', 'Week 41 2024'): 123,
#  ('Pakistan', 'Week 31 2024'): 123,
#  ('Bangladesh', 'Week 34 2024'): 122,
#  ('Sudan', 'Week 30 2024'): 122,
#  ('Nigeria', 'Week 38 2024'): 120,
#  ('Pakistan', 'Week 35 2024'): 120,
#  ('Israel', 'Week 21 2024'): 117,
#  ('South Sudan', 'Week 37 2024'): 117,
#  ('South Sudan', 'Week 31 2024'): 115,
#  ('Israel', 'Week 30 2024'): 114,
#  ('Israel', 'Week 37 2024'): 114,
#  ('Sudan', 'Week 27 2024'): 114,
#  ('India', 'Week 35 2024'): 111,
#  ('Mexico', 'Week 30 2024'): 111,
#  ('Mexico', 'Week 31 2024'): 111,
#  ('South Sudan', 'Week 32 2024'): 111,
#  ('Nigeria', 'Week 39 2024'): 110,
#  ('Philippines', 'Week 36 2024'): 109,
#  ('South Sudan', 'Week 39 2024'): 109,
#  ('Yemen', 'Week 32 2024'): 109,
#  ('Israel', 'Week 32 2024'): 108,
#  ('Israel', 'Week 42 2024'): 108,
#  ('Yemen', 'Week 35 2024'): 108,
#  ('South Sudan', 'Week 38 2024'): 107,
#  ('Sudan', 'Week 28 2024'): 106,
#  ('Afghanistan', 'Week 21 2024'): 105,
#  ('Afghanistan', 'Week 25 2024'): 105,
#  ('Israel', 'Week 27 2024'): 105,
#  ('Egypt', 'Week 19 2024'): 104,
#  ('Israel', 'Week 33 2024'): 104,
#  ('China', 'Week 36 2024'): 103,
#  ('India', 'Week 27 2024'): 103,
#  ('Philippines', 'Week 29 2024'): 103,
#  ('Nigeria', 'Week 20 2024'): 102,
#  ('South Sudan', 'Week 41 2024'): 102,
#  ('Sudan', 'Week 23 2024'): 102,
#  ('South Sudan', 'Week 36 2024'): 101,
#  ('Pakistan', 'Week 32 2024'): 99,
#  ('South Sudan', 'Week 34 2024'): 99,
#  ('Pakistan', 'Week 34 2024'): 98,
#  ('South Sudan', 'Week 30 2024'): 98,
#  ('Indonesia', 'Week 39 2024'): 97,
#  ('Pakistan', 'Week 36 2024'): 97,
#  ('South Sudan', 'Week 40 2024'): 97,
#  ('Sudan', 'Week 22 2024'): 97,
#  ('Bangladesh', 'Week 35 2024'): 96,
#  ('China', 'Week 30 2024'): 96,
#  ('Pakistan', 'Week 28 2024'): 96,
#  ('Palestinian Territory', 'Week 18 2024'): 95,
#  ('Ukraine', 'Week 21 2024'): 94,
#  ('Yemen', 'Week 31 2024'): 94,
#  ('Israel', 'Week 38 2024'): 93,
#  ('Ukraine', 'Week 24 2024'): 93,
#  ('Yemen', 'Week 30 2024'): 93,
#  ('France', 'Week 35 2024'): 92,
#  ('India', 'Week 33 2024'): 92,
#  ('Indonesia', 'Week 20 2024'): 92,
#  ('Lebanon', 'Week 42 2024'): 92,
#  ('Philippines', 'Week 31 2024'): 92,
#  ('Yemen', 'Week 34 2024'): 92,
#  ('India', 'Week 32 2024'): 91,
#  ('India', 'Week 39 2024'): 91,
#  ('Ukraine', 'Week 20 2024'): 91,
#  ('Australia', 'Week 30 2024'): 90,
#  ('Ethiopia', 'Week 30 2024'): 89,
#  ('Israel', 'Week 26 2024'): 89,
#  ('Nigeria', 'Week 24 2024'): 89,
#  ('Pakistan', 'Week 29 2024'): 88,
#  ('Afghanistan', 'Week 35 2024'): 87,
#  ('Nigeria', 'Week 41 2024'): 87,
#  ('Philippines', 'Week 37 2024'): 87,
#  ('South Africa', 'Week 37 2024'): 87,
#  ('South Sudan', 'Week 35 2024'): 87,
#  ('Afghanistan', 'Week 33 2024'): 86,
#  ('Afghanistan', 'Week 36 2024'): 86,
#  ('Kenya', 'Week 29 2024'): 86,
#  ('Pakistan', 'Week 33 2024'): 86,
#  ('Philippines', 'Week 28 2024'): 86,
#  ('Yemen', 'Week 37 2024'): 86,
#  ('India', 'Week 37 2024'): 85,
#  ('Jamaica', 'Week 37 2024'): 85,
#  ('Kenya', 'Week 30 2024'): 85,
#  ('South Africa', 'Week 31 2024'): 85,
#  ('Ukraine', 'Week 36 2024'): 85,
#  ('Yemen', 'Week 33 2024'): 85,
#  ('Kenya', 'Week 37 2024'): 84,
#  ('Kenya', 'Week 40 2024'): 84,
#  ('Mexico', 'Week 29 2024'): 84,
#  ('Nigeria', 'Week 19 2024'): 84,
#  ('Pakistan', 'Week 30 2024'): 84,
#  ('Kenya', 'Week 19 2024'): 83,
#  ('Kenya', 'Week 36 2024'): 83,
#  ('South Africa', 'Week 30 2024'): 83,
#  ('Ukraine', 'Week 23 2024'): 83,
#  ('Ukraine', 'Week 37 2024'): 83,
#  ('Yemen', 'Week 38 2024'): 83,
#  ('Yemen', 'Week 39 2024'): 83,
#  ('Afghanistan', 'Week 31 2024'): 82,
#  ('Myanmar', 'Week 37 2024'): 82,
#  ('Nigeria', 'Week 25 2024'): 82,
#  ('Nigeria', 'Week 27 2024'): 82,
#  ('Sudan', 'Week 20 2024'): 82,
#  ('Ukraine', 'Week 29 2024'): 82,
#  ('Ukraine', 'Week 30 2024'): 82,
#  ('Ukraine', 'Week 39 2024'): 82,
#  ('China', 'Week 40 2024'): 81,
#  ('Egypt', 'Week 35 2024'): 81,
#  ('India', 'Week 36 2024'): 81,
#  ('Bangladesh', 'Week 22 2024'): 80,
#  ('China', 'Week 38 2024'): 80,
#  ('Mexico', 'Week 37 2024'): 80,
#  ('Pakistan', 'Week 37 2024'): 80,
#  ('Pakistan', 'Week 39 2024'): 80,
#  ('Ukraine', 'Week 28 2024'): 80,
#  ('Ukraine', 'Week 32 2024'): 80,
#  ('China', 'Week 25 2024'): 79,
#  ('India', 'Week 22 2024'): 79,
#  ('France', 'Week 36 2024'): 78,
#  ('India', 'Week 29 2024'): 78,
#  ('Iran', 'Week 39 2024'): 78,
#  ('Jamaica', 'Week 31 2024'): 78,
#  ('Kenya', 'Week 31 2024'): 78,
#  ('South Africa', 'Week 39 2024'): 78,
#  ('Ukraine', 'Week 25 2024'): 78,
#  ('Egypt', 'Week 28 2024'): 77,
#  ('Egypt', 'Week 36 2024'): 77,
#  ('India', 'Week 28 2024'): 77,
#  ('Jamaica', 'Week 30 2024'): 77,
#  ('Jamaica', 'Week 39 2024'): 77,
#  ('Mexico', 'Week 23 2024'): 77,
#  ('Mexico', 'Week 38 2024'): 77,
#  ('Nigeria', 'Week 26 2024'): 77,
#  ('Israel', 'Week 18 2024'): 76,
#  ('Kenya', 'Week 39 2024'): 76,
#  ('Pakistan', 'Week 25 2024'): 76,
#  ('Pakistan', 'Week 27 2024'): 76,
#  ('United Kingdom', 'Week 31 2024'): 76,
#  ('Yemen', 'Week 41 2024'): 76,
#  ('France', 'Week 32 2024'): 75,
#  ('France', 'Week 40 2024'): 75,
#  ('India', 'Week 40 2024'): 75,
#  ('Philippines', 'Week 39 2024'): 75,
#  ('South Africa', 'Week 35 2024'): 75,
#  ('South Africa', 'Week 38 2024'): 75,
#  ('Sudan', 'Week 19 2024'): 75,
#  ('Ukraine', 'Week 35 2024'): 75,
#  ('Yemen', 'Week 40 2024'): 75,
#  ('Bangladesh', 'Week 32 2024'): 74,
#  ('China', 'Week 35 2024'): 74,
#  ('France', 'Week 27 2024'): 74,
#  ('France', 'Week 41 2024'): 74,
#  ('Jamaica', 'Week 36 2024'): 74,
#  ('Mexico', 'Week 35 2024'): 74,
#  ('Afghanistan', 'Week 19 2024'): 73,
#  ('Afghanistan', 'Week 20 2024'): 73,
#  ('France', 'Week 38 2024'): 73,
#  ('India', 'Week 38 2024'): 73,
#  ('Iran', 'Week 40 2024'): 73,
#  ('Jamaica', 'Week 28 2024'): 73,
#  ('Mexico', 'Week 19 2024'): 73,
#  ('Russia', 'Week 41 2024'): 73,
#  ('Philippines', 'Week 38 2024'): 72,
#  ('Sudan', 'Week 21 2024'): 72,
#  ('Sudan', 'Week 42 2024'): 72,
#  ('Ukraine', 'Week 38 2024'): 72,
#  ('India', 'Week 25 2024'): 71,
#  ('Nigeria', 'Week 22 2024'): 71,
#  ('Afghanistan', 'Week 30 2024'): 70,
#  ('Bangladesh', 'Week 27 2024'): 70,
#  ('Myanmar', 'Week 38 2024'): 70,
#  ('Nigeria', 'Week 40 2024'): 70,
#  ('Yemen', 'Week 29 2024'): 70,
#  ('Yemen', 'Week 36 2024'): 70,
#  ('Bangladesh', 'Week 36 2024'): 69,
#  ('China', 'Week 29 2024'): 69,
#  ('Indonesia', 'Week 19 2024'): 69,
#  ('Mexico', 'Week 21 2024'): 69,
#  ('Mexico', 'Week 22 2024'): 69,
#  ('Mexico', 'Week 28 2024'): 69,
#  ('Nigeria', 'Week 21 2024'): 69,
#  ('Philippines', 'Week 25 2024'): 69,
#  ('Philippines', 'Week 41 2024'): 69,
#  ('South Africa', 'Week 41 2024'): 69,
#  ('South Sudan', 'Week 24 2024'): 69,
#  ('Syria', 'Week 40 2024'): 69,
#  ('Kenya', 'Week 32 2024'): 68,
#  ('Afghanistan', 'Week 28 2024'): 67,
#  ('Afghanistan', 'Week 32 2024'): 67,
#  ('China', 'Week 27 2024'): 67,
#  ('France', 'Week 30 2024'): 67,
#  ('Indonesia', 'Week 41 2024'): 67,
#  ('Pakistan', 'Week 41 2024'): 67,
#  ('South Africa', 'Week 32 2024'): 67,
#  ('Switzerland', 'Week 25 2024'): 67,
#  ('Ukraine', 'Week 31 2024'): 67,
#  ('China', 'Week 31 2024'): 66,
#  ('France', 'Week 34 2024'): 66,
#  ('Indonesia', 'Week 21 2024'): 66,
#  ('Indonesia', 'Week 35 2024'): 66,
#  ('Ukraine', 'Week 34 2024'): 66,
#  ('Vietnam', 'Week 38 2024'): 66,
#  ('Afghanistan', 'Week 29 2024'): 65,
#  ('Egypt', 'Week 34 2024'): 65,
#  ('Indonesia', 'Week 40 2024'): 65,
#  ('Mexico', 'Week 34 2024'): 65,
#  ('Pakistan', 'Week 19 2024'): 65,
#  ('Philippines', 'Week 40 2024'): 65,
#  ('Russia', 'Week 30 2024'): 65,
#  ('Switzerland', 'Week 33 2024'): 65,
#  ('Thailand', 'Week 40 2024'): 65,
#  ('France', 'Week 29 2024'): 64,
#  ('India', 'Week 30 2024'): 64,
#  ('Indonesia', 'Week 32 2024'): 64,
#  ('Iran', 'Week 41 2024'): 64,
#  ('Jamaica', 'Week 40 2024'): 64,
#  ('Mexico', 'Week 27 2024'): 64,
#  ('Ukraine', 'Week 26 2024'): 64,
#  ('Ukraine', 'Week 27 2024'): 64,
#  ('Ethiopia', 'Week 33 2024'): 63,
#  ('Ethiopia', 'Week 34 2024'): 63,
#  ('France', 'Week 37 2024'): 63,
#  ('India', 'Week 21 2024'): 63,
#  ('India', 'Week 23 2024'): 63,
#  ('Kenya', 'Week 18 2024'): 63,
#  ('Myanmar', 'Week 34 2024'): 63,
#  ('Nigeria', 'Week 31 2024'): 63,
#  ('Pakistan', 'Week 23 2024'): 63,
#  ('South Africa', 'Week 20 2024'): 63,
#  ('South Africa', 'Week 21 2024'): 63,
#  ('Syria', 'Week 41 2024'): 63,
#  ('Ukraine', 'Week 22 2024'): 63,
#  ('Canada', 'Week 40 2024'): 62,
#  ('Democratic Republic of the Congo', 'Week 33 2024'): 62,
#  ('Ethiopia', 'Week 32 2024'): 62,
#  ('Indonesia', 'Week 31 2024'): 62,
#  ('Jamaica', 'Week 38 2024'): 62,
#  ('Mexico', 'Week 25 2024'): 62,
#  ('Mexico', 'Week 33 2024'): 62,
#  ('Nigeria', 'Week 32 2024'): 62,
#  ('Pakistan', 'Week 38 2024'): 62,
#  ('South Africa', 'Week 24 2024'): 62,
#  ('South Africa', 'Week 28 2024'): 62,
#  ('South Africa', 'Week 33 2024'): 62,
#  ('South Africa', 'Week 36 2024'): 62,
#  ('Thailand', 'Week 37 2024'): 62,
#  ('Ukraine', 'Week 33 2024'): 62,
#  ('Ukraine', 'Week 40 2024'): 62,
#  ('Chad', 'Week 35 2024'): 61,
#  ('Egypt', 'Week 33 2024'): 61,
#  ('Egypt', 'Week 37 2024'): 61,
#  ('France', 'Week 22 2024'): 61,
#  ('France', 'Week 31 2024'): 61,
#  ('France', 'Week 39 2024'): 61,
#  ('Germany', 'Week 32 2024'): 61,
#  ('Haiti', 'Week 40 2024'): 61,
#  ('Indonesia', 'Week 28 2024'): 61,
#  ('Kenya', 'Week 33 2024'): 61,
#  ('Lebanon', 'Week 38 2024'): 61,
#  ('Mexico', 'Week 32 2024'): 61,
#  ('Philippines', 'Week 33 2024'): 61,
#  ('Switzerland', 'Week 19 2024'): 61,
#  ('Egypt', 'Week 20 2024'): 60,
#  ('Egypt', 'Week 24 2024'): 60,
#  ('France', 'Week 24 2024'): 60,
#  ('Iraq', 'Week 31 2024'): 60,
#  ('Kenya', 'Week 41 2024'): 60,
#  ('Nepal', 'Week 40 2024'): 60,
#  ('Nigeria', 'Week 23 2024'): 60,
#  ('South Sudan', 'Week 29 2024'): 60,
#  ('Switzerland', 'Week 37 2024'): 60,
#  ('Bangladesh', 'Week 33 2024'): 59,
#  ('China', 'Week 41 2024'): 59,
#  ('Egypt', 'Week 32 2024'): 59,
#  ('Ethiopia', 'Week 31 2024'): 59,
#  ('France', 'Week 23 2024'): 59,
#  ('Japan', 'Week 35 2024'): 59,
#  ('Mexico', 'Week 36 2024'): 59,
#  ('South Africa', 'Week 25 2024'): 59,
#  ('Canada', 'Week 39 2024'): 58,
#  ('Democratic Republic of the Congo', 'Week 35 2024'): 58,
#  ('Egypt', 'Week 22 2024'): 58,
#  ('Kenya', 'Week 28 2024'): 58,
#  ('Switzerland', 'Week 35 2024'): 58,
#  ('Switzerland', 'Week 40 2024'): 58,
#  ('Yemen', 'Week 28 2024'): 58,
#  ('Afghanistan', 'Week 27 2024'): 57,
#  ('Australia', 'Week 31 2024'): 57,
#  ('France', 'Week 25 2024'): 57,
#  ('Iraq', 'Week 34 2024'): 57,
#  ('Jamaica', 'Week 32 2024'): 57,
#  ('Kenya', 'Week 34 2024'): 57,
#  ('Nigeria', 'Week 30 2024'): 57,
#  ('Russia', 'Week 24 2024'): 57,
#  ('Turkmenistan', 'Week 30 2024'): 57,
#  ('Afghanistan', 'Week 26 2024'): 56,
#  ('Afghanistan', 'Week 34 2024'): 56,
#  ('Afghanistan', 'Week 41 2024'): 56,
#  ('Canada', 'Week 41 2024'): 56,
#  ('Democratic Republic of the Congo', 'Week 36 2024'): 56,
#  ('France', 'Week 20 2024'): 56,
#  ('France', 'Week 28 2024'): 56,
#  ('India', 'Week 41 2024'): 56,
#  ('Jamaica', 'Week 29 2024'): 56,
#  ('Jamaica', 'Week 34 2024'): 56,
#  ('Nigeria', 'Week 28 2024'): 56,
#  ('South Africa', 'Week 34 2024'): 56,
#  ('Switzerland', 'Week 29 2024'): 56,
#  ('Afghanistan', 'Week 40 2024'): 55,
#  ('Bangladesh', 'Week 28 2024'): 55,
#  ('Bangladesh', 'Week 37 2024'): 55,
#  ('China', 'Week 39 2024'): 55,
#  ('Democratic Republic of the Congo', 'Week 32 2024'): 55,
#  ('Egypt', 'Week 29 2024'): 55,
#  ('Egypt', 'Week 40 2024'): 55,
#  ('Iran', 'Week 31 2024'): 55,
#  ('Kenya', 'Week 35 2024'): 55,
#  ('Nigeria', 'Week 29 2024'): 55,
#  ('Russia', 'Week 32 2024'): 55,
#  ('Russia', 'Week 37 2024'): 55,
#  ('Switzerland', 'Week 24 2024'): 55,
#  ('Switzerland', 'Week 31 2024'): 55,
#  ('Brazil', 'Week 19 2024'): 54,
#  ('Democratic Republic of the Congo', 'Week 31 2024'): 54,
#  ('France', 'Week 21 2024'): 54,
#  ('France', 'Week 26 2024'): 54,
#  ('France', 'Week 33 2024'): 54,
#  ('Iraq', 'Week 32 2024'): 54,
#  ('Iraq', 'Week 33 2024'): 54,
#  ('Lebanon', 'Week 35 2024'): 54,
#  ('Nigeria', 'Week 36 2024'): 54,
#  ('Philippines', 'Week 32 2024'): 54,
#  ('Switzerland', 'Week 39 2024'): 54,
#  ('Turkey', 'Week 32 2024'): 54,
#  ('Ukraine', 'Week 19 2024'): 54,
#  ('Afghanistan', 'Week 23 2024'): 53,
#  ('Afghanistan', 'Week 24 2024'): 53,
#  ('Australia', 'Week 32 2024'): 53,
#  ('Australia', 'Week 35 2024'): 53,
#  ('Democratic Republic of the Congo', 'Week 34 2024'): 53,
#  ('Democratic Republic of the Congo', 'Week 38 2024'): 53,
#  ('Jamaica', 'Week 33 2024'): 53,
#  ('Kenya', 'Week 21 2024'): 53,
#  ('Pakistan', 'Week 21 2024'): 53,
#  ('Philippines', 'Week 23 2024'): 53,
#  ('South Africa', 'Week 23 2024'): 53,
#  ('Switzerland', 'Week 34 2024'): 53,
#  ('Syria', 'Week 31 2024'): 53,
#  ('Afghanistan', 'Week 37 2024'): 52,
#  ('Australia', 'Week 36 2024'): 52,
#  ('Democratic Republic of the Congo', 'Week 37 2024'): 52,
#  ('Japan', 'Week 37 2024'): 52,
#  ('Kenya', 'Week 27 2024'): 52,
#  ('Pakistan', 'Week 26 2024'): 52,
#  ('Egypt', 'Week 21 2024'): 51,
#  ('Iran', 'Week 21 2024'): 51,
#  ('Iran', 'Week 32 2024'): 51,
#  ('Iran', 'Week 35 2024'): 51,
#  ('South Africa', 'Week 40 2024'): 51,
#  ('Syria', 'Week 28 2024'): 51,
#  ('Yemen', 'Week 27 2024'): 51,
#  ('Brazil', 'Week 20 2024'): 50,
#  ('Chad', 'Week 34 2024'): 50,
#  ('Democratic Republic of the Congo', 'Week 27 2024'): 50,
#  ('India', 'Week 24 2024'): 50,
#  ('Indonesia', 'Week 22 2024'): 50,
#  ('Indonesia', 'Week 34 2024'): 50,
#  ('Jamaica', 'Week 35 2024'): 50,
#  ('Philippines', 'Week 19 2024'): 50,
#  ('Philippines', 'Week 22 2024'): 50,
#  ('Russia', 'Week 26 2024'): 50,
#  ('Saint Helena', 'Week 41 2024'): 50,
#  ('South Africa', 'Week 22 2024'): 50,
#  ('South Sudan', 'Week 28 2024'): 50,
#  ('Switzerland', 'Week 38 2024'): 50,
#  ('Yemen', 'Week 19 2024'): 50,
#  ('Bangladesh', 'Week 25 2024'): 49,
#  ('Canada', 'Week 32 2024'): 49,
#  ('Egypt', 'Week 25 2024'): 49,
#  ('Haiti', 'Week 41 2024'): 49,
#  ('Indonesia', 'Week 30 2024'): 49,
#  ('Iraq', 'Week 41 2024'): 49,
#  ('Mexico', 'Week 24 2024'): 49,
#  ('Switzerland', 'Week 28 2024'): 49,
#  ('Ukraine', 'Week 41 2024'): 49,
#  ('Yemen', 'Week 24 2024'): 49,
#  ('Democratic Republic of the Congo', 'Week 40 2024'): 48,
#  ('Ethiopia', 'Week 28 2024'): 48,
#  ('Pakistan', 'Week 22 2024'): 48,
#  ('Pakistan', 'Week 40 2024'): 48,
#  ('Philippines', 'Week 35 2024'): 48,
#  ('Russia', 'Week 31 2024'): 48,
#  ('South Africa', 'Week 27 2024'): 48,
#  ('Afghanistan', 'Week 39 2024'): 47,
#  ('Central African Republic', 'Week 29 2024'): 47,
#  ('Egypt', 'Week 31 2024'): 47,
#  ('France', 'Week 19 2024'): 47,
#  ('India', 'Week 26 2024'): 47,
#  ('Indonesia', 'Week 37 2024'): 47,
#  ('Iraq', 'Week 35 2024'): 47,
#  ('Iraq', 'Week 37 2024'): 47,
#  ('Jamaica', 'Week 41 2024'): 47,
#  ('Mexico', 'Week 26 2024'): 47,
#  ('Myanmar', 'Week 35 2024'): 47,
#  ('Nigeria', 'Week 35 2024'): 47,
#  ('Philippines', 'Week 21 2024'): 47,
#  ('Philippines', 'Week 26 2024'): 47,
#  ('Russia', 'Week 36 2024'): 47,
#  ('Switzerland', 'Week 41 2024'): 47,
#  ('Taiwan', 'Week 30 2024'): 47,
#  ('Bangladesh', 'Week 21 2024'): 46,
#  ('China', 'Week 34 2024'): 46,
#  ('Ethiopia', 'Week 29 2024'): 46,
#  ('Germany', 'Week 23 2024'): 46,
#  ('Iran', 'Week 30 2024'): 46,
#  ('Italy', 'Week 32 2024'): 46,
#  ('Italy', 'Week 37 2024'): 46,
#  ('Mexico', 'Week 20 2024'): 46,
#  ('Philippines', 'Week 27 2024'): 46,
#  ('Somalia', 'Week 26 2024'): 46,
#  ('United Kingdom', 'Week 24 2024'): 46,
#  ('Bangladesh', 'Week 41 2024'): 45,
#  ('Ethiopia', 'Week 38 2024'): 45,
#  ('Indonesia', 'Week 23 2024'): 45,
#  ('Indonesia', 'Week 24 2024'): 45,
#  ('Indonesia', 'Week 27 2024'): 45,
#  ('Indonesia', 'Week 33 2024'): 45,
#  ('Pakistan', 'Week 24 2024'): 45,
#  ('Syria', 'Week 36 2024'): 45,
#  ('United Kingdom', 'Week 33 2024'): 45,
#  ('Australia', 'Week 22 2024'): 44,
#  ('Canada', 'Week 30 2024'): 44,
#  ('Chad', 'Week 31 2024'): 44,
#  ('Democratic Republic of the Congo', 'Week 23 2024'): 44,
#  ('Iraq', 'Week 28 2024'): 44,
#  ('Italy', 'Week 36 2024'): 44,
#  ('Kenya', 'Week 20 2024'): 44,
#  ('Kenya', 'Week 38 2024'): 44,
#  ('Mexico', 'Week 42 2024'): 44,
#  ('Philippines', 'Week 34 2024'): 44,
#  ('Syria', 'Week 22 2024'): 44,
#  ('Syria', 'Week 29 2024'): 44,
#  ('Turkey', 'Week 36 2024'): 44,
#  ('Uganda', 'Week 30 2024'): 44,
#  ('Chad', 'Week 32 2024'): 43,
#  ('Germany', 'Week 35 2024'): 43,
#  ('Ghana', 'Week 41 2024'): 43,
#  ('Indonesia', 'Week 26 2024'): 43,
#  ('Kenya', 'Week 26 2024'): 43,
#  ('Myanmar', 'Week 27 2024'): 43,
#  ('Philippines', 'Week 20 2024'): 43,
#  ('Syria', 'Week 21 2024'): 43,
#  ('United Kingdom', 'Week 39 2024'): 43,
#  ('Canada', 'Week 31 2024'): 42,
#  ('Canada', 'Week 36 2024'): 42,
#  ('Democratic Republic of the Congo', 'Week 25 2024'): 42,
#  ('Egypt', 'Week 41 2024'): 42,
#  ('Indonesia', 'Week 38 2024'): 42,
#  ('Iraq', 'Week 30 2024'): 42,
#  ('Italy', 'Week 30 2024'): 42,
#  ('Italy', 'Week 35 2024'): 42,
#  ('Lebanon', 'Week 36 2024'): 42,
#  ('Nigeria', 'Week 18 2024'): 42,
#  ('Nigeria', 'Week 33 2024'): 42,
#  ('Papua New Guinea', 'Week 22 2024'): 42,
#  ('Russia', 'Week 35 2024'): 42,
#  ('Russia', 'Week 40 2024'): 42,
#  ('Somalia', 'Week 30 2024'): 42,
#  ('South Africa', 'Week 29 2024'): 42,
#  ('South Sudan', 'Week 42 2024'): 42,
#  ('Switzerland', 'Week 21 2024'): 42,
#  ('Switzerland', 'Week 27 2024'): 42,
#  ('Thailand', 'Week 38 2024'): 42,
#  ('Turkey', 'Week 41 2024'): 42,
#  ('Uganda', 'Week 33 2024'): 42,
#  ('Vietnam', 'Week 36 2024'): 42,
#  ('Australia', 'Week 34 2024'): 41,
#  ('Bangladesh', 'Week 31 2024'): 41,
#  ('China', 'Week 26 2024'): 41,
#  ('Ethiopia', 'Week 25 2024'): 41,
#  ('Indonesia', 'Week 18 2024'): 41,
#  ('Japan', 'Week 38 2024'): 41,
#  ('Myanmar', 'Week 21 2024'): 41,
#  ('Myanmar', 'Week 39 2024'): 41,
#  ('Russia', 'Week 21 2024'): 41,
#  ('Russia', 'Week 29 2024'): 41,
#  ('Russia', 'Week 38 2024'): 41,
#  ('South Africa', 'Week 19 2024'): 41,
#  ('South Africa', 'Week 26 2024'): 41,
#  ('Syria', 'Week 39 2024'): 41,
#  ('Syria', 'Week 42 2024'): 41,
#  ('Turkey', 'Week 28 2024'): 41,
#  ('Afghanistan', 'Week 22 2024'): 40,
#  ('Australia', 'Week 29 2024'): 40,
#  ('Bonaire, Saint Eustatius and Saba ', 'Week 28 2024'): 40,
#  ('Canada', 'Week 28 2024'): 40,
#  ('Central African Republic', 'Week 34 2024'): 40,
#  ('China', 'Week 20 2024'): 40,
#  ('Democratic Republic of the Congo', 'Week 41 2024'): 40,
#  ('Egypt', 'Week 23 2024'): 40,
#  ('Egypt', 'Week 27 2024'): 40,
#  ('Egypt', 'Week 30 2024'): 40,
#  ('India', 'Week 19 2024'): 40,
#  ('Indonesia', 'Week 36 2024'): 40,
#  ('Myanmar', 'Week 20 2024'): 40,
#  ('Russia', 'Week 20 2024'): 40,
#  ('Russia', 'Week 28 2024'): 40,
#  ('South Korea', 'Week 35 2024'): 40,
#  ('South Sudan', 'Week 25 2024'): 40,
#  ('Switzerland', 'Week 22 2024'): 40,
#  ('Turkey', 'Week 33 2024'): 40,
#  ('Uganda', 'Week 35 2024'): 40,
#  ('United Kingdom', 'Week 35 2024'): 40,
#  ('Yemen', 'Week 26 2024'): 40,
#  ('Afghanistan', 'Week 38 2024'): 39,
#  ('Bangladesh', 'Week 26 2024'): 39,
#  ('Central African Republic', 'Week 35 2024'): 39,
#  ('China', 'Week 24 2024'): 39,
#  ('Ethiopia', 'Week 26 2024'): 39,
#  ('Ethiopia', 'Week 40 2024'): 39,
#  ('Iraq', 'Week 40 2024'): 39,
#  ('Italy', 'Week 38 2024'): 39,
#  ('Kenya', 'Week 25 2024'): 39,
#  ('Nigeria', 'Week 34 2024'): 39,
#  ('Philippines', 'Week 24 2024'): 39,
#  ('Russia', 'Week 22 2024'): 39,
#  ('Russia', 'Week 25 2024'): 39,
#  ('Somalia', 'Week 28 2024'): 39,
#  ('Turkey', 'Week 31 2024'): 39,
#  ('Ukraine', 'Week 18 2024'): 39,
#  ('Australia', 'Week 37 2024'): 38,
#  ('China', 'Week 22 2024'): 38,
#  ('China', 'Week 28 2024'): 38,
#  ('Democratic Republic of the Congo', 'Week 29 2024'): 38,
#  ('Ethiopia', 'Week 24 2024'): 38,
#  ('Ethiopia', 'Week 35 2024'): 38,
#  ('France', 'Week 42 2024'): 38,
#  ('Iran', 'Week 25 2024'): 38,
#  ('Italy', 'Week 27 2024'): 38,
#  ('Italy', 'Week 34 2024'): 38,
#  ('Italy', 'Week 40 2024'): 38,
#  ('Jordan', 'Week 24 2024'): 38,
#  ('Myanmar', 'Week 25 2024'): 38,
#  ('Nepal', 'Week 39 2024'): 38,
#  ('Saint Vincent and the Grenadines', 'Week 28 2024'): 38,
#  ('South Sudan', 'Week 27 2024'): 38,
#  ('Sudan', 'Week 18 2024'): 38,
#  ('Switzerland', 'Week 36 2024'): 38,
#  ('Turkey', 'Week 30 2024'): 38,
#  ('Turkey', 'Week 35 2024'): 38,
#  ('United Kingdom', 'Week 23 2024'): 38,
#  ('Bangladesh', 'Week 29 2024'): 37,
#  ('Canada', 'Week 38 2024'): 37,
#  ('Democratic Republic of the Congo', 'Week 21 2024'): 37,
#  ('Democratic Republic of the Congo', 'Week 28 2024'): 37,
#  ('France', 'Week 18 2024'): 37,
#  ('Ghana', 'Week 40 2024'): 37,
#  ('Iran', 'Week 34 2024'): 37,
#  ('Italy', 'Week 31 2024'): 37,
#  ('Jamaica', 'Week 42 2024'): 37,
#  ('Japan', 'Week 39 2024'): 37,
#  ('Kenya', 'Week 24 2024'): 37,
#  ('Kenya', 'Week 42 2024'): 37,
#  ('Puerto Rico', 'Week 41 2024'): 37,
#  ('Somalia', 'Week 39 2024'): 37,
#  ('Syria', 'Week 27 2024'): 37,
#  ('Syria', 'Week 37 2024'): 37,
#  ('United Kingdom', 'Week 21 2024'): 37,
#  ('United Kingdom', 'Week 27 2024'): 37,
#  ('Uruguay', 'Week 41 2024'): 37,
#  ('Australia', 'Week 33 2024'): 36,
#  ('Brazil', 'Week 40 2024'): 36,
#  ('Canada', 'Week 24 2024'): 36,
#  ('Canada', 'Week 33 2024'): 36,
#  ('Chad', 'Week 37 2024'): 36,
#  ('Ethiopia', 'Week 20 2024'): 36,
#  ('Germany', 'Week 24 2024'): 36,
#  ('Indonesia', 'Week 25 2024'): 36,
#  ('Iran', 'Week 33 2024'): 36,
#  ('Iran', 'Week 37 2024'): 36,
#  ('Italy', 'Week 28 2024'): 36,
#  ('Myanmar', 'Week 31 2024'): 36,
#  ('Pakistan', 'Week 20 2024'): 36,
#  ('United Kingdom', 'Week 25 2024'): 36,
#  ('Australia', 'Week 28 2024'): 35,
#  ('Bangladesh', 'Week 24 2024'): 35,
#  ('Bangladesh', 'Week 30 2024'): 35,
#  ('Cameroon', 'Week 40 2024'): 35,
#  ('China', 'Week 32 2024'): 35,
#  ('Democratic Republic of the Congo', 'Week 19 2024'): 35,
#  ('Georgia', 'Week 40 2024'): 35,
#  ('India', 'Week 20 2024'): 35,
#  ('Iran', 'Week 38 2024'): 35,
#  ('Myanmar', 'Week 28 2024'): 35,
#  ('Russia', 'Week 23 2024'): 35,
#  ('Somalia', 'Week 33 2024'): 35,
#  ('South Sudan', 'Week 20 2024'): 35,
#  ('Yemen', 'Week 20 2024'): 35,
#  ('Australia', 'Week 25 2024'): 34,
#  ('Australia', 'Week 41 2024'): 34,
#  ('Bangladesh', 'Week 39 2024'): 34,
#  ('Bonaire, Saint Eustatius and Saba ', 'Week 39 2024'): 34,
#  ('Central African Republic', 'Week 31 2024'): 34,
#  ('Central African Republic', 'Week 36 2024'): 34,
#  ('Egypt', 'Week 26 2024'): 34,
#  ('Ethiopia', 'Week 27 2024'): 34,
#  ('India', 'Week 42 2024'): 34,
#  ('Iraq', 'Week 36 2024'): 34,
#  ('Jamaica', 'Week 21 2024'): 34,
#  ('Jordan', 'Week 29 2024'): 34,
#  ('Kenya', 'Week 22 2024'): 34,
#  ('Myanmar', 'Week 26 2024'): 34,
#  ('Myanmar', 'Week 32 2024'): 34,
#  ('Myanmar', 'Week 33 2024'): 34,
#  ('Somalia', 'Week 19 2024'): 34,
#  ('South Africa', 'Week 42 2024'): 34,
#  ('Syria', 'Week 26 2024'): 34,
#  ('Turkey', 'Week 19 2024'): 34,
#  ('Uganda', 'Week 34 2024'): 34,
#  ('United Kingdom', 'Week 30 2024'): 34,
#  ('United Kingdom', 'Week 38 2024'): 34,
#  ('United Kingdom', 'Week 40 2024'): 34,
#  ('Brazil', 'Week 39 2024'): 33,
#  ('Canada', 'Week 37 2024'): 33,
#  ('Central African Republic', 'Week 42 2024'): 33,
#  ('Egypt', 'Week 39 2024'): 33,
#  ('Ethiopia', 'Week 36 2024'): 33,
#  ('Ethiopia', 'Week 39 2024'): 33,
#  ('Ethiopia', 'Week 41 2024'): 33,
#  ('Germany', 'Week 40 2024'): 33,
#  ('Indonesia', 'Week 29 2024'): 33,
#  ('Italy', 'Week 39 2024'): 33,
#  ('Italy', 'Week 41 2024'): 33,
#  ('Lebanon', 'Week 23 2024'): 33,
#  ('Myanmar', 'Week 40 2024'): 33,
#  ('Qatar', 'Week 35 2024'): 33,
#  ('Russia', 'Week 27 2024'): 33,
#  ('Somalia', 'Week 20 2024'): 33,
#  ('Somalia', 'Week 31 2024'): 33,
#  ('Switzerland', 'Week 20 2024'): 33,
#  ('Switzerland', 'Week 23 2024'): 33,
#  ('Syria', 'Week 35 2024'): 33,
#  ('Taiwan', 'Week 40 2024'): 33,
#  ('Thailand', 'Week 41 2024'): 33,
#  ('Turkey', 'Week 27 2024'): 33,
#  ('Ukraine', 'Week 42 2024'): 33,
#  ('Australia', 'Week 38 2024'): 32,
#  ('Australia', 'Week 39 2024'): 32,
#  ('Brazil', 'Week 21 2024'): 32,
#  ('Chad', 'Week 33 2024'): 32,
#  ('Iran', 'Week 22 2024'): 32,
#  ('Iraq', 'Week 39 2024'): 32,
#  ('Jamaica', 'Week 24 2024'): 32,
#  ('Mozambique', 'Week 19 2024'): 32,
#  ('Myanmar', 'Week 29 2024'): 32,
#  ('Qatar', 'Week 28 2024'): 32,
#  ('Russia', 'Week 34 2024'): 32,
#  ('Russia', 'Week 39 2024'): 32,
#  ('Somalia', 'Week 24 2024'): 32,
#  ('Syria', 'Week 33 2024'): 32,
#  ('Syria', 'Week 38 2024'): 32,
#  ('Turkey', 'Week 37 2024'): 32,
#  ('Yemen', 'Week 21 2024'): 32,
#  ('Yemen', 'Week 23 2024'): 32,
#  ('Canada', 'Week 34 2024'): 31,
#  ('Central African Republic', 'Week 37 2024'): 31,
#  ('China', 'Week 33 2024'): 31,
#  ('Egypt', 'Week 38 2024'): 31,
#  ('Ethiopia', 'Week 37 2024'): 31,
#  ('Germany', 'Week 28 2024'): 31,
#  ('Haiti', 'Week 39 2024'): 31,
#  ('Jamaica', 'Week 27 2024'): 31,
#  ('Japan', 'Week 33 2024'): 31,
#  ('Lebanon', 'Week 32 2024'): 31,
#  ('Lebanon', 'Week 33 2024'): 31,
#  ('Libya', 'Week 37 2024'): 31,
#  ('Morocco', 'Week 41 2024'): 31,
#  ('Mozambique', 'Week 31 2024'): 31,
#  ('Paraguay', 'Week 40 2024'): 31,
#  ('Qatar', 'Week 34 2024'): 31,
#  ('Russia', 'Week 33 2024'): 31,
#  ('Somalia', 'Week 32 2024'): 31,
#  ('Somalia', 'Week 41 2024'): 31,
#  ('Switzerland', 'Week 26 2024'): 31,
#  ('Syria', 'Week 19 2024'): 31,
#  ('Syria', 'Week 23 2024'): 31,
#  ('Uganda', 'Week 36 2024'): 31,
#  ('Angola', 'Week 27 2024'): 30,
#  ('Bangladesh', 'Week 19 2024'): 30,
#  ('Brazil', 'Week 29 2024'): 30,
#  ('Canada', 'Week 35 2024'): 30,
#  ('Chad', 'Week 29 2024'): 30,
#  ('Chad', 'Week 41 2024'): 30,
#  ('Czechia', 'Week 32 2024'): 30,
#  ('Egypt', 'Week 18 2024'): 30,
#  ('Germany', 'Week 30 2024'): 30,
#  ('Ghana', 'Week 34 2024'): 30,
#  ('Indonesia', 'Week 42 2024'): 30,
#  ('Iran', 'Week 19 2024'): 30,
#  ('Iran', 'Week 24 2024'): 30,
#  ('Iraq', 'Week 38 2024'): 30,
#  ('Italy', 'Week 33 2024'): 30,
#  ('Jamaica', 'Week 22 2024'): 30,
#  ('Jamaica', 'Week 25 2024'): 30,
#  ('Jordan', 'Week 36 2024'): 30,
#  ('Myanmar', 'Week 19 2024'): 30,
#  ('Nigeria', 'Week 42 2024'): 30,
#  ('Philippines', 'Week 42 2024'): 30,
#  ('Somalia', 'Week 29 2024'): 30,
#  ('Somalia', 'Week 34 2024'): 30,
#  ('South Sudan', 'Week 19 2024'): 30,
#  ('Thailand', 'Week 36 2024'): 30,
#  ('Turkey', 'Week 34 2024'): 30,
#  ('Uganda', 'Week 32 2024'): 30,
#  ('United Kingdom', 'Week 20 2024'): 30,
#  ('United Kingdom', 'Week 22 2024'): 30,
#  ('United Kingdom', 'Week 36 2024'): 30,
#  ('Australia', 'Week 21 2024'): 29,
#  ('Bangladesh', 'Week 40 2024'): 29,
#  ('Cameroon', 'Week 28 2024'): 29,
#  ('Canada', 'Week 29 2024'): 29,
#  ('Chad', 'Week 28 2024'): 29,
#  ('China', 'Week 21 2024'): 29,
#  ('Democratic Republic of the Congo', 'Week 30 2024'): 29,
#  ('Ethiopia', 'Week 22 2024'): 29,
#  ('Germany', 'Week 31 2024'): 29,
#  ('Grenada', 'Week 28 2024'): 29,
#  ('Haiti', 'Week 37 2024'): 29,
#  ('Iran', 'Week 27 2024'): 29,
#  ('Iran', 'Week 28 2024'): 29,
#  ('Iran', 'Week 36 2024'): 29,
#  ('Mexico', 'Week 18 2024'): 29,
#  ('Myanmar', 'Week 41 2024'): 29,
#  ('Nepal', 'Week 28 2024'): 29,
#  ('Pakistan', 'Week 18 2024'): 29,
#  ('Pakistan', 'Week 42 2024'): 29,
#  ('Rwanda', 'Week 21 2024'): 29,
#  ('Somalia', 'Week 23 2024'): 29,
#  ('Somalia', 'Week 25 2024'): 29,
#  ('South Sudan', 'Week 26 2024'): 29,
#  ('Switzerland', 'Week 30 2024'): 29,
#  ('Turkey', 'Week 24 2024'): 29,
#  ('Turkey', 'Week 29 2024'): 29,
#  ('Australia', 'Week 40 2024'): 28,
#  ('Bangladesh', 'Week 23 2024'): 28,
#  ('Brazil', 'Week 31 2024'): 28,
#  ('Cameroon', 'Week 39 2024'): 28,
#  ('Chad', 'Week 22 2024'): 28,
#  ('Ecuador', 'Week 30 2024'): 28,
#  ('Germany', 'Week 29 2024'): 28,
#  ('Germany', 'Week 38 2024'): 28,
#  ('Haiti', 'Week 20 2024'): 28,
#  ('Italy', 'Week 26 2024'): 28,
#  ('Japan', 'Week 34 2024'): 28,
#  ('Japan', 'Week 36 2024'): 28,
#  ('Jordan', 'Week 37 2024'): 28,
#  ('Kenya', 'Week 23 2024'): 28,
#  ('Laos', 'Week 38 2024'): 28,
#  ('Libya', 'Week 28 2024'): 28,
#  ('Morocco', 'Week 37 2024'): 28,
#  ('Mozambique', 'Week 34 2024'): 28,
#  ('Nepal', 'Week 41 2024'): 28,
#  ('Paraguay', 'Week 30 2024'): 28,
#  ('Paraguay', 'Week 33 2024'): 28,
#  ('Syria', 'Week 30 2024'): 28,
#  ('Tanzania', 'Week 31 2024'): 28,
#  ('Thailand', 'Week 34 2024'): 28,
#  ('Uganda', 'Week 37 2024'): 28,
#  ('United Kingdom', 'Week 29 2024'): 28,
#  ('Vietnam', 'Week 39 2024'): 28,
#  ('Yemen', 'Week 22 2024'): 28,
#  ('Afghanistan', 'Week 18 2024'): 27,
#  ('Bonaire, Saint Eustatius and Saba ', 'Week 27 2024'): 27,
#  ('Brazil', 'Week 27 2024'): 27,
#  ('Brazil', 'Week 30 2024'): 27,
#  ('Cameroon', 'Week 37 2024'): 27,
#  ('Chad', 'Week 25 2024'): 27,
#  ('Chad', 'Week 38 2024'): 27,
#  ('China', 'Week 23 2024'): 27,
#  ('Colombia', 'Week 41 2024'): 27,
#  ('Commonwealth of Independent States', 'Week 25 2024'): 27,
#  ('Egypt', 'Week 42 2024'): 27,
#  ('Ethiopia', 'Week 23 2024'): 27,
#  ('Japan', 'Week 32 2024'): 27,
#  ('Lebanon', 'Week 34 2024'): 27,
#  ('Myanmar', 'Week 42 2024'): 27,
#  ('Paraguay', 'Week 37 2024'): 27,
#  ('Qatar', 'Week 36 2024'): 27,
#  ('Russia', 'Week 19 2024'): 27,
#  ('South Sudan', 'Week 23 2024'): 27,
#  ('Spain', 'Week 31 2024'): 27,
#  ('Syria', 'Week 24 2024'): 27,
#  ('Turkey', 'Week 22 2024'): 27,
#  ('Uganda', 'Week 39 2024'): 27,
#  ('Uganda', 'Week 41 2024'): 27,
#  ('United Kingdom', 'Week 26 2024'): 27,
#  ('United Kingdom', 'Week 37 2024'): 27,
#  ('Vietnam', 'Week 40 2024'): 27,
#  ('Yemen', 'Week 42 2024'): 27,
#  ('Australia', 'Week 19 2024'): 26,
#  ('Brazil', 'Week 41 2024'): 26,
#  ('Cameroon', 'Week 36 2024'): 26,
#  ('Canada', 'Week 21 2024'): 26,
#  ('Central African Republic', 'Week 33 2024'): 26,
#  ('China', 'Week 18 2024'): 26,
#  ('Ethiopia', 'Week 18 2024'): 26,
#  ('Ethiopia', 'Week 19 2024'): 26,
#  ('Georgia', 'Week 39 2024'): 26,
#  ('Ghana', 'Week 29 2024'): 26,
#  ('Ghana', 'Week 36 2024'): 26,
#  ('Ghana', 'Week 38 2024'): 26,
#  ('Iraq', 'Week 42 2024'): 26,
#  ('Italy', 'Week 24 2024'): 26,
#  ('Morocco', 'Week 28 2024'): 26,
#  ('Morocco', 'Week 36 2024'): 26,
#  ('Myanmar', 'Week 30 2024'): 26,
#  ('Myanmar', 'Week 36 2024'): 26,
#  ('Paraguay', 'Week 41 2024'): 26,
#  ('Puerto Rico', 'Week 40 2024'): 26,
#  ('Qatar', 'Week 19 2024'): 26,
#  ('Somalia', 'Week 27 2024'): 26,
#  ('Spain', 'Week 25 2024'): 26,
#  ('Turkey', 'Week 40 2024'): 26,
#  ('Uganda', 'Week 31 2024'): 26,
#  ('Uganda', 'Week 40 2024'): 26,
#  ('Yemen', 'Week 25 2024'): 26,
#  ('Zambia', 'Week 20 2024'): 26,
#  ('Zambia', 'Week 39 2024'): 26,
#  ('Angola', 'Week 33 2024'): 25,
#  ('Australia', 'Week 20 2024'): 25,
#  ('Bangladesh', 'Week 20 2024'): 25,
#  ('Bonaire, Saint Eustatius and Saba ', 'Week 31 2024'): 25,
#  ('Brazil', 'Week 18 2024'): 25,
#  ('Brazil', 'Week 23 2024'): 25,
#  ('Brazil', 'Week 37 2024'): 25,
#  ('Brazil', 'Week 38 2024'): 25,
#  ('Burkina Faso', 'Week 41 2024'): 25,
#  ('Canada', 'Week 20 2024'): 25,
#  ('Central African Republic', 'Week 28 2024'): 25,
#  ('Chad', 'Week 36 2024'): 25,
#  ('Commonwealth of Independent States', 'Week 19 2024'): 25,
#  ('Ecuador', 'Week 41 2024'): 25,
#  ('Ethiopia', 'Week 21 2024'): 25,
#  ('Germany', 'Week 39 2024'): 25,
#  ('Haiti', 'Week 30 2024'): 25,
#  ('Jordan', 'Week 31 2024'): 25,
#  ('Jordan', 'Week 35 2024'): 25,
#  ('Lebanon', 'Week 31 2024'): 25,
#  ('Lebanon', 'Week 37 2024'): 25,
#  ('Morocco', 'Week 35 2024'): 25,
#  ('Mozambique', 'Week 35 2024'): 25,
#  ('Paraguay', 'Week 28 2024'): 25,
#  ('Paraguay', 'Week 35 2024'): 25,
#  ('Qatar', 'Week 33 2024'): 25,
#  ('Rwanda', 'Week 19 2024'): 25,
#  ('Rwanda', 'Week 32 2024'): 25,
#  ('Somalia', 'Week 21 2024'): 25,
#  ('South Sudan', 'Week 21 2024'): 25,
#  ('Spain', 'Week 35 2024'): 25,
#  ('Tanzania', 'Week 18 2024'): 25,
#  ('Zambia', 'Week 19 2024'): 25,
#  ('Zambia', 'Week 22 2024'): 25,
#  ('Zambia', 'Week 40 2024'): 25,
#  ('Zimbabwe', 'Week 31 2024'): 25,
#  ('Zimbabwe', 'Week 41 2024'): 25,
#  ('Angola', 'Week 19 2024'): 24,
#  ('Angola', 'Week 23 2024'): 24,
#  ('Angola', 'Week 40 2024'): 24,
#  ('Bangladesh', 'Week 38 2024'): 24,
#  ('Cameroon', 'Week 41 2024'): 24,
#  ('Chad', 'Week 20 2024'): 24,
#  ('Ecuador', 'Week 38 2024'): 24,
#  ('Germany', 'Week 33 2024'): 24,
#  ('Germany', 'Week 36 2024'): 24,
#  ('Ghana', 'Week 37 2024'): 24,
#  ('India', 'Week 18 2024'): 24,
#  ('Iran', 'Week 42 2024'): 24,
#  ('Iraq', 'Week 26 2024'): 24,
#  ('Jamaica', 'Week 20 2024'): 24,
#  ('Lebanon', 'Week 27 2024'): 24,
#  ('Morocco', 'Week 31 2024'): 24,
#  ('Mozambique', 'Week 22 2024'): 24,
#  ('Mozambique', 'Week 32 2024'): 24,
#  ('Mozambique', 'Week 39 2024'): 24,
#  ('Mozambique', 'Week 41 2024'): 24,
#  ('Myanmar', 'Week 22 2024'): 24,
#  ('Qatar', 'Week 23 2024'): 24,
#  ('Somalia', 'Week 35 2024'): 24,
#  ('Somalia', 'Week 36 2024'): 24,
#  ('Spain', 'Week 39 2024'): 24,
#  ('Thailand', 'Week 31 2024'): 24,
#  ('Thailand', 'Week 39 2024'): 24,
#  ('United Kingdom', 'Week 28 2024'): 24,
#  ('Afghanistan', 'Week 42 2024'): 23,
#  ('Bonaire, Saint Eustatius and Saba ', 'Week 29 2024'): 23,
#  ('Cameroon', 'Week 38 2024'): 23,
#  ('Chile', 'Week 29 2024'): 23,
#  ('China', 'Week 19 2024'): 23,
#  ('Commonwealth of Independent States', 'Week 21 2024'): 23,
#  ('Commonwealth of Independent States', 'Week 23 2024'): 23,
#  ('Democratic Republic of the Congo', 'Week 26 2024'): 23,
#  ('Democratic Republic of the Congo', 'Week 39 2024'): 23,
#  ('Ecuador', 'Week 21 2024'): 23,
#  ('Ecuador', 'Week 31 2024'): 23,
#  ('Germany', 'Week 34 2024'): 23,
#  ('Ghana', 'Week 19 2024'): 23,
#  ('Guatemala', 'Week 22 2024'): 23,
#  ('Haiti', 'Week 29 2024'): 23,
#  ...}

# %% [markdown]
# ## Filtering by country-period

# %%
import random 
random.seed(121)

key_country, key_period = "Afghanistan" , "Week 21 2024" #random.choice(list(ndocs_dict.keys()) )
filterted_data = full_data[(full_data['country'].isin( [key_country])  )& (full_data['publish_week'] == key_period)]

titles = list(filterted_data['title'])

# %%
filterted_data
# Out:
#        Unnamed: 0    id_x                            article_id  \
# 134         49525  106031  c3aa9841-3920-3eec-ae03-5f6b1ffefc90
# 135         49525  106031  c3aa9841-3920-3eec-ae03-5f6b1ffefc90
# 138         49688  106200  6fb64723-0285-3e7f-baee-b50215b744ec
# 139         49688  106200  6fb64723-0285-3e7f-baee-b50215b744ec
# 1762        50892  107415  f1e9de82-16ad-3491-b69d-b3306cc3d3eb
# ...           ...     ...                                   ...
# 84660       50936  107460  d4cb5a89-c82a-313d-bc02-2e1148abadc4
# 84790       50119  106631  3f995037-a30a-3f71-b10a-3361a4ffeafc
# 84793       50119  106631  3f995037-a30a-3f71-b10a-3361a4ffeafc
# 84810       50173  106685  3f995037-a30a-3f71-b10a-3361a4ffeafc
# 84814       50173  106685  3f995037-a30a-3f71-b10a-3361a4ffeafc
#
#                                                    title  \
# 134            Spain urges its citizens to leave Lebanon
# 135            Spain urges its citizens to leave Lebanon
# 138            Spain urges its citizens to leave Lebanon
# 139            Spain urges its citizens to leave Lebanon
# 1762   Syria - Displacement from Lebanon to Syria (DG...
# ...                                                  ...
# 84660  PALESTINE One year of hostilities: impact on e...
# 84790  Gaza humanitarian response update | 16-29 Sept...
# 84793  Gaza humanitarian response update | 16-29 Sept...
# 84810                Gaza Humanitarian 29 September 2024
# 84814                Gaza Humanitarian 29 September 2024
#
#                                                  content lang  \
# 134    Spain urges its citizens to leave Lebanon\nSpa...   en
# 135    Spain urges its citizens to leave Lebanon\nSpa...   en
# 138    Spain urges its citizens to leave Lebanon\nSpa...   en
# 139    Spain urges its citizens to leave Lebanon\nSpa...   en
# 1762   - With the escalation of hostilities between I...   en
# ...                                                  ...  ...
# 84660  PALESTINE One year of hostilities: impact on e...   en
# 84790  The information below is provided every other ...   en
# 84793  The information below is provided every other ...   en
# 84810  Children benefitting from informal learning ac...   en
# 84814  Children benefitting from informal learning ac...   en
#
#                               attachment_id content_type  \
# 134                                     NaN         html
# 135                                     NaN         html
# 138                                     NaN         html
# 139                                     NaN         html
# 1762                                    NaN         html
# ...                                     ...          ...
# 84660  c5c046c2-6d00-3d3a-9b30-6f4b5baf89fe          pdf
# 84790                                   NaN         html
# 84793                                   NaN         html
# 84810  f5649e98-14cc-3cf2-b9fe-d9a9fef0fd4d          pdf
# 84814  f5649e98-14cc-3cf2-b9fe-d9a9fef0fd4d          pdf
#
#                                                      url     source_domain  \
# 134    https://www.naharnet.com:443/stories/en/308396...  naharnet.com:443
# 135    https://www.naharnet.com:443/stories/en/308396...  naharnet.com:443
# 138    https://naharnet.com/stories/en/308396-spain-u...      naharnet.com
# 139    https://naharnet.com/stories/en/308396-spain-u...      naharnet.com
# 1762   https://reliefweb.int/report/syrian-arab-repub...     reliefweb.int
# ...                                                  ...               ...
# 84660  https://reliefweb.int/attachments/f585e9a5-eee...     reliefweb.int
# 84790  https://reliefweb.int/report/occupied-palestin...     reliefweb.int
# 84793  https://reliefweb.int/report/occupied-palestin...     reliefweb.int
# 84810  https://reliefweb.int/attachments/b85778d2-ec7...     reliefweb.int
# 84814  https://reliefweb.int/attachments/b85778d2-ec7...     reliefweb.int
#
#              publish_date duplicate_insert_time    id_y  clean_contents_id  \
# 134   2024-10-01 00:00:00                   NaT  106162             106031
# 135   2024-10-01 00:00:00                   NaT  106162             106031
# 138   2024-10-01 00:00:00                   NaT  106305             106200
# 139   2024-10-01 00:00:00                   NaT  106305             106200
# 1762  2024-10-04 11:13:32                   NaT  107465             107415
# ...                   ...                   ...     ...                ...
# 84660 2024-10-04 13:57:29                   NaT  107403             107460
# 84790 2024-10-02 19:17:03                   NaT  106716             106631
# 84793 2024-10-02 19:17:03                   NaT  106716             106631
# 84810 2024-10-02 19:17:03                   NaT  106784             106685
# 84814 2024-10-02 19:17:03                   NaT  106784             106685
#
#                                                 keywords  \
# 134    ['spain urges', 'leave lebanon', 'citizens', '...
# 135    ['spain urges', 'leave lebanon', 'citizens', '...
# 138    ['spain urges', 'leave lebanon', 'citizens', '...
# 139    ['spain urges', 'leave lebanon', 'citizens', '...
# 1762   ['dg echo', 'unhcr', 'syria', 'sarc', 'lebanon...
# ...                                                  ...
# 84660  ['impact', 'hostilities', 'gaza', 'education',...
# 84790  ['16', 'whole population', 'west bank', 'warm ...
# 84793  ['16', 'whole population', 'west bank', 'warm ...
# 84810  ['whole population', 'west bank', 'warm clothe...
# 84814  ['whole population', 'west bank', 'warm clothe...
#
#                      country  \
# 134                   Israel
# 135    Palestinian Territory
# 138                   Israel
# 139    Palestinian Territory
# 1762                  Israel
# ...                      ...
# 84660                 Israel
# 84790  Palestinian Territory
# 84793                 Israel
# 84810  Palestinian Territory
# 84814                 Israel
#
#                                             country_json  publish_week  \
# 134    {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 135    {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 138    {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 139    {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 1762   {'geo_loc': {'Syria': {'latitude': 35.0, 'geon...  Week 40 2024
# ...                                                  ...           ...
# 84660  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 84790  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 84793  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 84810  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 84814  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
#
#       publish_month
# 134    October 2024
# 135    October 2024
# 138    October 2024
# 139    October 2024
# 1762   October 2024
# ...             ...
# 84660  October 2024
# 84790  October 2024
# 84793  October 2024
# 84810  October 2024
# 84814  October 2024
#
# [335 rows x 19 columns]

# %% [markdown]
# ## Manual filtering based on the title

# %%
key_country, key_period
# Out:
# ('Afghanistan', 'Week 21 2024')

# %%
import openai 
def call_openai (prompt, max_tokens): 
    client = openai.OpenAI(api_key=" " )

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=max_tokens
    )
    
    # Extract the model's score
    response = response.choices[0].message.content.strip()
    
    return response

# %%
import openai 
titles = filterted_data['title'].tolist()

prompt_topic = """
Here are several document titles. Please identify the main event or topic that most of these titles are related to, and provide the most common event/topic. 
Return just the main event/topic, nothing else.  
Here the titles:
:\n\n
""" 


for title in titles:
    prompt_topic+= title + "\n" 

main_topic = call_openai(prompt_topic, max_tokens=30)

# %%
main_topic
# Out:
# 'Afghanistan Floods'

# %%
for idx, title in enumerate(titles):
    print(idx, title)
# Out:
# 0 Afghanistan: Minutes of FSAC Monthly Meeting (15 November 2023) [Meeting Minutes]
# 1 Faces of the floods
# 2 DTM Pakistan: Bi-Weekly Flow Monitoring of Afghan Returnees from Pakistan (1 - 15 May 2024)
# 3 Guideline on Food Security and Agriculture Cluster Response Packages (May 2024)
# 4 Afghanistan: Minutes of FSAC Monthly Meeting (20 March 2023) [Meeting Minutes]
# 5 Afghanistan floods affect over 30,000 since year-start: UN
# 6 Afghanistan: Border Consortium Emergency Border Operations, 05 - 18 May 2024
# 7 WHO distributes 25 tons of aid to flood victims in Afghanistan's Ghor
# 8 WFP identifies conflict as primary cause of global hunger crisis
# 9 Afghanistan Floods Flash Update #2 (21 May 2024)
# 10 UNICEF Afghanistan Humanitarian Situation Update No. 2 (Northern Region Flash Floods) for 26 May 2024.
# 11 Shelter Cluster Afghanistan: Regional Monthly Update (April 2024)
# 12 Afghanistan Flooding Situation Report No. 5 (17 - 20 May 2024)
# 13 Afghanistan Floods: Flash Update #3 - Floods hit the Northeastern Region of Afghanistan (22 May 2024)
# 14 UNICEF Afghanistan Humanitarian Situation Update No. 1 (Northern Region Flash Floods): 20 May 2024
# 15 Afghanistan: Countrywide Weekly Market Report: Issue 200: Week 3 May 2024
# 16 Shelter Cluster Afghanistan: Shelter Needs & Advocacy Dashboard on Floods and Heavy Rainfall Events (January - 14 May 2024)
# 17 UN expresses concern over rise in child marriages in Afghanistan
# 18 Over 3,000 Afghan migrants deported from Iran and Pakistan
# 19 Afghanistan Health Cluster Bulletin, April 2024
# 20 Multi-Sectoral Rapid Needs Assessment (MRAT) of Afghan returnees (April 2024)
# 21 Double jeopardy - during and after conflict: The human cost of weapon contamination in Asia-Pacific
# 22 Afghanistan: Minutes of FSAC Monthly Meeting (17 January 2024) [Meeting Minutes]
# 23 SIGAR 24-23 Financial Audit - Department of State’s Children’s Support Center Project in Afghanistan: Audit of Costs Incurred by Women for Afghan Women Inc. - Afghanistan
# 24 Afghanistan Floods: Humanitarian Update Situation Report #1 May 14, 2024
# 25 Addressing winter challenges: Our cash distributions help Afghans in need
# 26 Afghanistan: Minutes of FSAC Monthly Meeting (28 February 2024) [Meeting Minutes]
# 27 DTM Afghanistan: Weekly Flow Monitoring Snapshot (12 - 18 May 2024)
# 28 DTM Afghanistan: Weekly Flow Monitoring Snapshot (12 - 18 May 2024) [EN/Dari/PS]
# 29 Afghanistan Floods: Humanitarian Update Situation Report #2 May 21, 2024
# 30 Afghanistan WFP Flash Appeal: Floods - May 2024
# 31 Afghanistan Floods: Humanitarian Update Situation Report #2 May 21, 2024
# 32 Govt to assist relocation for residents affected by West Sumatra flood
# 33 UNHCR-IOM Pakistan Flash Update #20: Arrest and Detention/Flow Monitoring (15 September 2023 - 18 May 2024)
# 34 Singapore Red Cross donates $50k to Afghanistan flood relief and launches appeal for funds
# 35 Afghanistan Protection Analysis Update - Update on protracted-crisis and climate-related protection risks trends, May 2024
# 36 AFGHANISTAN BAGHLAN-E-JADID DISTRICT, BAGHLAN PROVINCE
# 37 Afghanistan floods highlight risks of extreme weather events to children
# 38 Govt designing community-based early warning system for flash floods
# 39 Indonesia is Designing Community-based Early Warning System for Flash Floods in West Sumatra
# 40 WFP Afghanistan: Situation Report, April 2024
# 41 Protection Interventions for Afghan Returnees from Pakistan (April 2024 to December 2025)
# 42 [Afghanistan Flash Floods] Singapore Red Cross launches fundraising appeal; sends humanitarian aid to affected communities
# 43 Severe flooding in Afghanistan hunger hotspots is set to worsen, warns WFP
# 44 ACAPS Briefing note - Afghanistan: Impact of flooding (21 May 2024)
# 45 69°18'E AFGHANISTAN ESHKMESH DISTRICT, TAKHAR PROVINCE
# 46 Practical Solutions Where Needs Are Greatest - UNOPS 2023
# 47 Severe flooding in Afghanistan hunger hotspots is set to worsen, warns WFP
# 48 Afghanistan Emergency Situation Report Issue 39 (Reporting Period: April 2024)
# 49 Afghanistan Flooding Situation Report No. 6 (21 - 23 May 2024)
# 50 Afghanistan Floods: Flash Update #1 - Floods hit the Northern and Western Regions of Afghanistan (20 May 2024 )
# 51 Climate crisis fuels deadly floods, worsening hunger in Afghanistan
# 52 Asia and the Pacific: Weekly Regional Humanitarian Snapshot (14 - 20 May 2024)
# 53 The Azadi Briefing: Deadly Floods Worsen Hunger Crisis In Afghanistan
# 54 France begins first war crimes trial of Syrian officials
# 55 Afghanistan: Minutes of FSAC Monthly Meeting (24 April 2024) [Meeting Minutes]
# 56 MHTs provide maternal care, psychosocial support to flood-affected people in Baghlan
# 57 Fresh floods kill 66 in northern Afghanistan
# 58 Women’s Voice and Leadership in Humanitarian Settings (WHS): Baseline Study Report
# 59 Fistula survivor looks forward to reuniting with family after surgery
# 60 UN warns of more flooding in Afghanistan
# 61 #1 FLASH FLOODS RESPONSE UDPATE NORTHEAST
# 62 SITUATION UPDATE
# 63 SITUATION UPDATE
# 64 Strengthening Women-Led Organizations’ Meaningful Engagement in Humanitarian Settings: Year 1 Learnings
# 65 Türkiye sees off another aid train for flood-hit Afghanistan
# 66 Afghanistan needs long-term aid after floods
# 67 Pakistan: IPC Acute Food Insecurity Analysis March - November 2024 (Published on 23 May 2024)
# 68 Afghanistan: Stronger prevention measures needed amid measles surge
# 69 For more detailed information, please click here to refer to the meeting presentation.
# 70 Project Satisfaction at the Global Level 81%
# 71 Half a dozen killed in Afghanistan last week
# 72 ➢ ➢ ➢
# 73 Transitioning from Face-to-Face to Remote Capacity Sharing with 15 Cohort Members in Afghanistan
# 74 Transitioning from Face-to-Face to Remote Capacity Sharing with 15 Cohort Members in Afghanistan
# 75 o o o o o
# 76 Flash Appeal: Floods May 2024
# 77 Licence to probe: the liberating beauty of fiction after journalism
# 78 DTM PAKISTAN BI-WEEKLY FLOW MONITORING OF AFGHAN RETURNEES DATA COLLECTION PERIOD: 1 – 15 May 2024
# 79 Afghan Women Face Serious Challenges Amid Flooding
# 80 From Dream to Climate Action: Advancing Early Warnings for Flashfloods for All
# 81 WFP Afghanistan Situation Report
# 82 Refugees in Australia: Overcoming Adversity, Championing Change
# 83 Weekly Market Report Issue 200: Week 3 - May 2024
# 84 Artificial Intelligence and gender equality
# 85 March - November 2024 PAKISTAN: IPC Acute Food Insecurity Snapshot |
# 86 CCCM Cluster as of April 2024
# 87 CCCM Cluster as of April 2024
# 88 PAKISTAN-AFGHANISTAN Returns Emergency Response
# 89 o o o
# 90 DISPLACEMENT TRACKING MATRIX AFGHANISTAN WEEKLY FLOW MONITORING SNAPSHOT
# 91 DISPLACEMENT TRACKING MATRIX AFGHANISTAN WEEKLY FLOW MONITORING SNAPSHOT
# 92 Afghanistan Floods: Flash Update #1 Floods hit the Northern and Western Regions of Afghanistan
# 93 Northern Region Flash Floods Update #1
# 94 AFGHANISTAN FLOODS FLASH UPDATE #2 21 May 2024
# 95 Afghanistan Floods: Flash Update #3 Floods hit the Northeastern Region of Afghanistan
# 96 Northern and Western Region Flash Floods Update # 2
# 97 Impact of Cuts Outcome of 2023 pilot study: Impact of funding shortfalls on beneficiaries
# 98 Key messages:
# 99 Guideline on Food Security and Agriculture Cluster Response Packages
# 100 15 SEP 2023 - 18 MAY 2024 Torkham TOTAL RETURNEES 376.4K Spin Boldak 589.7K 196.1K
# 101 Key messages:
# 102 Protection Interventions for Afghan Returnees from Pakistan April 2024 to December 2025
# 103 BULLETIN APRIL 2024
# 104 MAY 2024

# %%
#this list is given by reading the titles by myself
remove_index = [2,6,17, 18,21,23,25,36,37,39,52,54,58, 62,63,67,70,72,75,77,78,84,89,96,104]
filterted_titles = [titles[idx] for idx in range(len(titles)) if idx not in remove_index]

selected_sources = filterted_data[filterted_data['title'].isin(filterted_titles) ]


remove_index = [1, 9, 77, 87, 102, 122, 123, 142, 143, 146, 154, 155, 171, 172, 175, 176, 177, 182, 183, 192, 202]
filtered_titles = {title for i, title in enumerate(selected_sources['title']) if i not in remove_index}
selected_sources = selected_sources[selected_sources['title'].isin(filtered_titles)]

# %%
for idx, title in enumerate(selected_sources['title']):
    print(idx, title)
# Out:
# 0 Afghanistan: Minutes of FSAC Monthly Meeting (15 November 2023) [Meeting Minutes]
# 1 Guideline on Food Security and Agriculture Cluster Response Packages (May 2024)
# 2 Afghanistan: Minutes of FSAC Monthly Meeting (20 March 2023) [Meeting Minutes]
# 3 Afghanistan floods affect over 30,000 since year-start: UN
# 4 WHO distributes 25 tons of aid to flood victims in Afghanistan's Ghor
# 5 WFP identifies conflict as primary cause of global hunger crisis
# 6 Afghanistan Floods Flash Update #2 (21 May 2024)
# 7 UNICEF Afghanistan Humanitarian Situation Update No. 2 (Northern Region Flash Floods) for 26 May 2024.
# 8 Afghanistan Flooding Situation Report No. 5 (17 - 20 May 2024)
# 9 Afghanistan Floods: Flash Update #3 - Floods hit the Northeastern Region of Afghanistan (22 May 2024)
# 10 UNICEF Afghanistan Humanitarian Situation Update No. 1 (Northern Region Flash Floods): 20 May 2024
# 11 Afghanistan: Countrywide Weekly Market Report: Issue 200: Week 3 May 2024
# 12 Shelter Cluster Afghanistan: Shelter Needs & Advocacy Dashboard on Floods and Heavy Rainfall Events (January - 14 May 2024)
# 13 Afghanistan Health Cluster Bulletin, April 2024
# 14 Multi-Sectoral Rapid Needs Assessment (MRAT) of Afghan returnees (April 2024)
# 15 Afghanistan: Minutes of FSAC Monthly Meeting (17 January 2024) [Meeting Minutes]
# 16 Afghanistan Floods: Humanitarian Update Situation Report #1 May 14, 2024
# 17 Afghanistan: Minutes of FSAC Monthly Meeting (28 February 2024) [Meeting Minutes]
# 18 DTM Afghanistan: Weekly Flow Monitoring Snapshot (12 - 18 May 2024)
# 19 DTM Afghanistan: Weekly Flow Monitoring Snapshot (12 - 18 May 2024) [EN/Dari/PS]
# 20 Afghanistan Floods: Humanitarian Update Situation Report #2 May 21, 2024
# 21 Afghanistan WFP Flash Appeal: Floods - May 2024
# 22 Afghanistan Floods: Humanitarian Update Situation Report #2 May 21, 2024
# 23 Govt to assist relocation for residents affected by West Sumatra flood
# 24 UNHCR-IOM Pakistan Flash Update #20: Arrest and Detention/Flow Monitoring (15 September 2023 - 18 May 2024)
# 25 Singapore Red Cross donates $50k to Afghanistan flood relief and launches appeal for funds
# 26 Afghanistan Protection Analysis Update - Update on protracted-crisis and climate-related protection risks trends, May 2024
# 27 Govt designing community-based early warning system for flash floods
# 28 WFP Afghanistan: Situation Report, April 2024
# 29 Protection Interventions for Afghan Returnees from Pakistan (April 2024 to December 2025)
# 30 [Afghanistan Flash Floods] Singapore Red Cross launches fundraising appeal; sends humanitarian aid to affected communities
# 31 Severe flooding in Afghanistan hunger hotspots is set to worsen, warns WFP
# 32 ACAPS Briefing note - Afghanistan: Impact of flooding (21 May 2024)
# 33 69°18'E AFGHANISTAN ESHKMESH DISTRICT, TAKHAR PROVINCE
# 34 Practical Solutions Where Needs Are Greatest - UNOPS 2023
# 35 Severe flooding in Afghanistan hunger hotspots is set to worsen, warns WFP
# 36 Afghanistan Emergency Situation Report Issue 39 (Reporting Period: April 2024)
# 37 Afghanistan Flooding Situation Report No. 6 (21 - 23 May 2024)
# 38 Afghanistan Floods: Flash Update #1 - Floods hit the Northern and Western Regions of Afghanistan (20 May 2024 )
# 39 Climate crisis fuels deadly floods, worsening hunger in Afghanistan
# 40 The Azadi Briefing: Deadly Floods Worsen Hunger Crisis In Afghanistan
# 41 Afghanistan: Minutes of FSAC Monthly Meeting (24 April 2024) [Meeting Minutes]
# 42 MHTs provide maternal care, psychosocial support to flood-affected people in Baghlan
# 43 Fresh floods kill 66 in northern Afghanistan
# 44 Fistula survivor looks forward to reuniting with family after surgery
# 45 UN warns of more flooding in Afghanistan
# 46 #1 FLASH FLOODS RESPONSE UDPATE NORTHEAST
# 47 Strengthening Women-Led Organizations’ Meaningful Engagement in Humanitarian Settings: Year 1 Learnings
# 48 Türkiye sees off another aid train for flood-hit Afghanistan
# 49 Afghanistan needs long-term aid after floods
# 50 Afghanistan: Stronger prevention measures needed amid measles surge
# 51 For more detailed information, please click here to refer to the meeting presentation.
# 52 Half a dozen killed in Afghanistan last week
# 53 Transitioning from Face-to-Face to Remote Capacity Sharing with 15 Cohort Members in Afghanistan
# 54 Transitioning from Face-to-Face to Remote Capacity Sharing with 15 Cohort Members in Afghanistan
# 55 Flash Appeal: Floods May 2024
# 56 Afghan Women Face Serious Challenges Amid Flooding
# 57 From Dream to Climate Action: Advancing Early Warnings for Flashfloods for All
# 58 WFP Afghanistan Situation Report
# 59 Refugees in Australia: Overcoming Adversity, Championing Change
# 60 Weekly Market Report Issue 200: Week 3 - May 2024
# 61 March - November 2024 PAKISTAN: IPC Acute Food Insecurity Snapshot |
# 62 CCCM Cluster as of April 2024
# 63 CCCM Cluster as of April 2024
# 64 PAKISTAN-AFGHANISTAN Returns Emergency Response
# 65 DISPLACEMENT TRACKING MATRIX AFGHANISTAN WEEKLY FLOW MONITORING SNAPSHOT
# 66 DISPLACEMENT TRACKING MATRIX AFGHANISTAN WEEKLY FLOW MONITORING SNAPSHOT
# 67 Afghanistan Floods: Flash Update #1 Floods hit the Northern and Western Regions of Afghanistan
# 68 Northern Region Flash Floods Update #1
# 69 AFGHANISTAN FLOODS FLASH UPDATE #2 21 May 2024
# 70 Afghanistan Floods: Flash Update #3 Floods hit the Northeastern Region of Afghanistan
# 71 Impact of Cuts Outcome of 2023 pilot study: Impact of funding shortfalls on beneficiaries
# 72 Key messages:
# 73 Guideline on Food Security and Agriculture Cluster Response Packages
# 74 15 SEP 2023 - 18 MAY 2024 Torkham TOTAL RETURNEES 376.4K Spin Boldak 589.7K 196.1K
# 75 Key messages:
# 76 Protection Interventions for Afghan Returnees from Pakistan April 2024 to December 2025
# 77 BULLETIN APRIL 2024

# %%
len(selected_sources)
# Out:
# 78

# %% [markdown]
# # Save dict of sources

# %%
# Set results
selected_sources = selected_sources.drop_duplicates(subset='content')

sources_dict = {
    index: f"title: {row['title']} \n content: {row['content']}"
    for index, row in selected_sources.iterrows()
}

len(selected_sources)
import json 

#with open(f"./Results/Sources-Gannet /sources-Gannet-{week}-{sector}.json", 'w') as f:
with open(f"./Results/SourcesCountryEvent/Other events/{key_country}_{main_topic}-{key_period}.json", 'w') as f:

    json.dump(sources_dict, f)

# %%
selected_sources
# Out:
#        Unnamed: 0    id_x                            article_id  \
# 3631        50297  106827  3fc4a398-ded7-32a4-a4b1-7bf1d0ac644a
# 6159        49162  105667  15a500d6-b54d-354a-8770-89c98712c018
# 6628        51530  108059  c7c526f4-0e70-3fc3-98d4-50fcb161ddf7
# 7943        51171  107696  97b58a07-3f97-3b2f-a235-e754b46d5b28
# 9375        50822  107345  4971a171-9e86-389c-ac67-334d39a211da
# ...           ...     ...                                   ...
# 81829       49244  105752  8897b3fe-c0a2-3a7d-9b38-f010b707afcb
# 81846       49201  105709  8897b3fe-c0a2-3a7d-9b38-f010b707afcb
# 84659       50936  107460  d4cb5a89-c82a-313d-bc02-2e1148abadc4
# 84790       50119  106631  3f995037-a30a-3f71-b10a-3361a4ffeafc
# 84810       50173  106685  3f995037-a30a-3f71-b10a-3361a4ffeafc
#
#                                                    title  \
# 3631   WFP Palestine Emergency Response External Situ...
# 6159   The United States Announces Nearly $336 Millio...
# 6628   UNICEF chief warns Gaza kids face ‘post-genera...
# 7943   Leaked emails show White House ignores early w...
# 9375   9 Palestinians killed as Gaza faces wrath of I...
# ...                                                  ...
# 81829                            Humanitarian Gaza Strip
# 81846    Humanitarian Situation Update #224 | Gaza Strip
# 84659  PALESTINE One year of hostilities: impact on e...
# 84790  Gaza humanitarian response update | 16-29 Sept...
# 84810                Gaza Humanitarian 29 September 2024
#
#                                                  content lang  \
# 3631   HIGHLIGHTS\n• In September to date, WFP reache...   en
# 6159   Office of Press Relations\npress@usaid.gov\nMo...   en
# 6628   After a year of military operations between Is...   en
# 7943   WASHINGTON, Oct. 5 (Xinhua) -- Leaked emails f...   en
# 9375   At least nine Palestinians were killed, and se...   en
# ...                                                  ...  ...
# 81829  Makeshift shelters leaving internally displace...   en
# 81846  The Humanitarian Situation Update is issued by...   en
# 84659  PALESTINE One year of hostilities: impact on e...   en
# 84790  The information below is provided every other ...   en
# 84810  Children benefitting from informal learning ac...   en
#
#                               attachment_id content_type  \
# 3631                                    NaN         html
# 6159                                    NaN         html
# 6628                                    NaN         html
# 7943                                    NaN         html
# 9375                                    NaN         html
# ...                                     ...          ...
# 81829  db2f33c3-0886-3a96-8204-19526a2f3342          pdf
# 81846                                   NaN         html
# 84659  c5c046c2-6d00-3d3a-9b30-6f4b5baf89fe          pdf
# 84790                                   NaN         html
# 84810  f5649e98-14cc-3cf2-b9fe-d9a9fef0fd4d          pdf
#
#                                                      url  \
# 3631   https://reliefweb.int/report/occupied-palestin...
# 6159   https://reliefweb.int/report/occupied-palestin...
# 6628   https://www.middleeastmonitor.com/20241006-uni...
# 7943   https://english.news.cn/20241005/709ff6adda3d4...
# 9375   https://www.dailysabah.com/world/mid-east/9-pa...
# ...                                                  ...
# 81829  https://reliefweb.int/attachments/01e445ad-77d...
# 81846  https://reliefweb.int/report/occupied-palestin...
# 84659  https://reliefweb.int/attachments/f585e9a5-eee...
# 84790  https://reliefweb.int/report/occupied-palestin...
# 84810  https://reliefweb.int/attachments/b85778d2-ec7...
#
#                source_domain        publish_date duplicate_insert_time  \
# 3631           reliefweb.int 2024-10-03 12:15:25                   NaT
# 6159           reliefweb.int 2024-09-30 21:15:50                   NaT
# 6628   middleeastmonitor.com 2024-10-06 17:20:00                   NaT
# 7943         english.news.cn 2024-10-05 00:00:00                   NaT
# 9375          dailysabah.com 2024-10-04 11:58:00                   NaT
# ...                      ...                 ...                   ...
# 81829          reliefweb.int 2024-09-30 17:49:15                   NaT
# 81846          reliefweb.int 2024-09-30 17:49:15                   NaT
# 84659          reliefweb.int 2024-10-04 13:57:29                   NaT
# 84790          reliefweb.int 2024-10-02 19:17:03                   NaT
# 84810          reliefweb.int 2024-10-02 19:17:03                   NaT
#
#          id_y  clean_contents_id  \
# 3631   107102             106827
# 6159   105724             105667
# 6628   108159             108059
# 7943   107787             107696
# 9375   107555             107345
# ...       ...                ...
# 81829  105712             105752
# 81846  105815             105709
# 84659  107403             107460
# 84790  106716             106631
# 84810  106784             106685
#
#                                                 keywords  \
# 3631   ['34', 'west bank', 'usual number', 'significa...
# 6159   ['west bank', 'support palestinians', 'humanit...
# 6628   ['vaccinating thousands', 'us ”', 'unicef warn...
# 7943   ['white house', 'west bank', 'used u', 'state ...
# 9375   ['israeli shelling', 'year since', 'territory ...
# ...                                                  ...
# 81829  ['“ safe', '“ marking', 'younger generation', ...
# 81846  ['gaza strip', '224', '“ safe', '“ marking', '...
# 84659  ['impact', 'hostilities', 'gaza', 'education',...
# 84790  ['16', 'whole population', 'west bank', 'warm ...
# 84810  ['whole population', 'west bank', 'warm clothe...
#
#                      country  \
# 3631   Palestinian Territory
# 6159   Palestinian Territory
# 6628   Palestinian Territory
# 7943   Palestinian Territory
# 9375   Palestinian Territory
# ...                      ...
# 81829  Palestinian Territory
# 81846  Palestinian Territory
# 84659  Palestinian Territory
# 84790  Palestinian Territory
# 84810  Palestinian Territory
#
#                                             country_json  publish_week  \
# 3631   {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 6159   {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 6628   {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 7943   {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 9375   {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# ...                                                  ...           ...
# 81829  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 81846  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 84659  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 84790  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
# 84810  {'geo_loc': {'Gaza': {'latitude': 31.50161, 'g...  Week 40 2024
#
#         publish_month
# 3631     October 2024
# 6159   September 2024
# 6628     October 2024
# 7943     October 2024
# 9375     October 2024
# ...               ...
# 81829  September 2024
# 81846  September 2024
# 84659    October 2024
# 84790    October 2024
# 84810    October 2024
#
# [115 rows x 19 columns]

# %%
for idx, title in enumerate(selected_sources['title']):
    print(idx, title)
# Out:
# 0 WFP Palestine Emergency Response External Situation Report #34 (02 October 2024)
# 1 The United States Announces Nearly $336 Million in Humanitarian Assistance to Support Palestinians in Gaza and the West Bank
# 2 UNICEF chief warns Gaza kids face ‘post-generational challenges’
# 3 Leaked emails show White House ignores early warning of Gaza humanitarian disaster
# 4 9 Palestinians killed as Gaza faces wrath of Israeli shelling
# 5 Verification of damages to schools based on proximity to damaged sites - Gaza, Occupied Palestinian Territory, Update #6 (September 2024)
# 6 Permission with conditions for pro-Palestine group protest
# 7 Palestinian authorities urge displaced Gazans to ignore new Israeli evacuation orders
# 8 At least 21 killed in Israeli airstrikes on homes, shelters across Gaza
# 9 Israeli army issues evacuation warning to residents of Bureij, Nuseirat refugee camps in Gaza
# 10 UN chief urges peace to end suffering ahead of Gaza war anniversary
# 11 US to announce over $335m in aid for Palestinians in Gaza, West Bank
# 12 UN chief appeals for peace ahead of Gaza war anniversary
# 13 Israeli army orders more evictions of northern Gaza residents after 100 air strikes since Saturday evening
# 14 Victims of Gaza remembered in Dutch church with recitation from Quran
# 15 Israeli airstrikes recently hit at least 6 schools sheltering displaced Palestinians: UN
# 16 In solidarity with Palestine, Indian poet rejects US-backed honor
# 17 Istanbul conference discusses Israel's genocidal war in Palestine
# 18 Israeli army orders more evictions of northern Gaza residents after 100 airstrikes since Saturday evening
# 19 Thunberg leads pro-Palestinian, climate protest in Milan
# 20 18 Palestinians killed in Israeli air strike on Tulkarm refugee camp
# 21 US to announce over $430m in aid for Palestinians in Gaza, West Bank
# 22 US to announce over US$300 million in aid for Palestinians in Gaza, West Bank
# 23 In #Gaza, over 1 million people did not receive food rations in August
# 24 'Time to stop the suffering': UN chief appeals for peace ahead of Gaza war anniversary
# 25 In #Gaza, over 1 million people did not receive food rations in August
# 26 EU boosts humanitarian aid to Lebanon by €30 million, bringing total to over €100 million for 2024
# 27 Israeli forces return to Jabaliya and issue new evacuation orders
# 28 Iran launches missile attack on Israel
# 29 IDF Launches Military Operation Against Hamas in North of Gaza Strip
# 30 West Bank: 18 reported killed in Israeli strike targeting Hamas figure
# 31 Israeli strike on Jabalia kills journalist Hassan Hamad
# 32 24 Palestinians killed in Israeli airstrikes on mosque, school sheltering displaced people in Gaza
# 33 3 children among 14 killed, several injured in Israeli airstrikes on central, northern Gaza
# 34 UN Human Rights Office - OPT: Strikes on internally displaced persons shelters - Gaza
# 35 ACAPS Briefing note: Lebanon - Escalation of hostilities: key humanitarian developments (01 October 2024)
# 36 25 Palestinians killed in Israeli airstrikes on Gaza
# 37 Guterres urges global community to repeat ‘utter condemnation’ of 7 October Hamas terror attack
# 38 UN condemns 'unlawful' Israeli airstrike on West Bank refugee camp, killing 18 Palestinians
# 39 UN Human Rights in Occupied Palestinian Territory
# 40 Life in Gaza, before and after the war: A doctor's story
# 41 Israeli forces return to Jabaliya and issue new evacuation orders
# 42 26 Palestinians killed in Israeli airstrikes on mosque, school sheltering displaced people in Gaza
# 43 One year of war in Gaza
# 44 'Brutal massacre': At least 18 Palestinians killed in Israeli air raid on Tulkarm
# 45 Israeli air and ground attacks kill at least 51 people across Gaza
# 46 'Palestinians were failed for years by both Conservative, Labour governments': Humza Yousaf condemns decades of inaction
# 47 EU boosts humanitarian aid to Lebanon by €30 million, bringing total to over €100 million for 2024
# 48 UN Human Rights Office Condemns Unlawful Airstrike on Tulkarem Camp, Calls for Accountability and Protection of Civilians
# 49 UN Human Rights Office - OPT: UN Human Rights Office Condemns Unlawful Airstrike on Tulkarem Camp, Calls for Accountability and Protection of Civilians - occupied Palestinian territory | ReliefWeb
# 50 Israel strikes target rescuers in Dahieh and south, killing 6
# 51 Syrian Minister denounces Israel for its ‘seven-decade-long criminal record’
# 52 Israeli strikes killed 21 Palestinians in Gaza, West Bank: sources
# 53 UN Human Rights in Occupied Palestinian Territory Ramallah
# 54 Ahead of attack anniversary, Netanyahu says: 'We will win'
# 55 MAG partners with local NGO to keep people safe from explosive ordnance in Gaza
# 56 99 US doctors who volunteered to work in Gaza say they have not seen any militant activity in hospitals
# 57 oPt Emergency Situation Update 46 (7 Oct 2023 - 25 Sep 2024)
# 58 Javier Bardem on Gaza: ‘We cannot remain indifferent while Israel commits war crimes’
# 59 Oxfam says more women, children killed by Israel in Gaza than in any other conflict in two decades
# 60 'No end to hell' in northern Gaza, warns UN aid agency chief
# 61 Relatives say whole family killed in Israel's deadliest West Bank strike since Oct. 7
# 62 Israeli military says it has encircled area of northern Gaza after seeing signs of Hamas regrouping
# 63 Gaza is one of the most dangerous places in the world to learn and teach - over 400 teachers have died in the war
# 64 ACAPS Briefing Note: Palestine - One year of hostilities: impact on education in Gaza (04 October 2024)
# 65 18 killed in Israeli strike on West Bank’s Tulkarem refugee camp: Ministry
# 66 As conflict in the Middle East widens, the IRC urges an immediate and lasting ceasefire to allow a devastated Gaza the essential aid and services needed - occupied Palestinian territory | ReliefWeb
# 67 White House warned of risk of Israeli war crimes days after Oct 7: Report
# 68 A year of massacre and misery: Israel’s nightmare campaign against Palestinian families in Gaza.
# 69 Gazans in the north trapped with nowhere to go, as fighting intensifies
# 70 Israeli army's intention to deliberately kill civilians and non-combatants and prevent aid and relief to them, disregarding international law
# 71 Rights expert urges universities to respect pro-Palestinian protests
# 72 Gaza: Geospatial data shows intensifying damage to cropland
# 73 Israel launches ground offensive on Jabalia again, killing 17
# 74 One year of unimaginable suffering since the 7 October attack [EN/AR/HE]
# 75 Collective trauma marks anniversary of Hamas attack on Israel
# 76 UN condemns deadly West Bank airstrike, attacks on Gaza schools
# 77 43 Palestinian fatalities
# 78 One year on, the world has failed civilians in Gaza, with terrifying global consequences
# 79 ‘Orphanage city’ helps children in Gaza as the war grinds on
# 80 One year on, Gaza residents face the worst nightmare as humanitarian crisis deepens with every passing day : Speakers
# 81 After Gaza, Wednesday 2 October 2024
# 82 Gaza: 1 Year On - Accountability Report
# 83 Israel-Gaza conflict: Only ceasefire can end suffering for civilians after catastrophic year
# 84 A letter from a mother in Gaza: Hardships, heartbreak and hope
# 85 Israel-UN relations sink to new depths
# 86 Letter to FIFA Council Members Re: Israeli Settlements and the Israel Football Association
# 87 UN warns against 'catastrophic' regional conflict
# 88 As a Palestinian living in the US, I have lost friends, job opportunities - and my faith in humanity
# 89 received food assistance 93,000 received cash assistance 45,700 since 23 September million people 1.2 Affected by the conflict
# 90 ‘I had to evacuate five times’: a year in the life of a Gaza doctor battling to help victims
# 91 What atrocity would Israel have to commit for our leaders to break their silence?
# 92 Israel-UN relations sink to new depths
# 93 Gaza’s survivors face the mental challenge of ongoing acute stress
# 94 New report.. De-Gaza: A Year of Israel’s Genocide and the Collapse of World Order
# 95 For the second time: Israel’s war machine targets Yemen’s power infrastructure [EN/AR]
# 96 One year of a war without rules has left Gaza shattered
# 97 Ecocide in Gaza - Newspaper - DAWN.COM
# 98 The Pooled Funds’ response to the escalation of conflict in the OCCUPIED PALESTINIAN TERRITORY 30 September 2024
# 99 WFP PALESTINE EMERGENCY RESPONSE External Situation Report 34
# 100 Israel and allies must bring year-long war in Gaza to an end
# 101 Israel Over Reported fatalities 1,200*** 1,162 identified fatalities, including at least 33 children Reported injuries ~5,400 Gaza****
# 102 De-Gaza: A Year of Israel’s Genocide and the Collapse of World Order [EN/AR]
# 103 Gaza: Israel’s destruction of hundreds of dunams of agricultural land is expression of its insistence on committing genocide [EN/AR]
# 104 A year of horror, vile political point-scoring and the oldest hatred hitting home. And yet I still hope
# 105 Enduring Unsanitary Conditions in Gaza
# 106 Amid all the darkness: How kindness helped me survive one year of Israel’s genocide in Gaza
# 107 More women and children killed in Gaza by Israeli military than any other recent conflict in a single year - Oxfam
# 108 Voices from Gaza on their year of hell: ‘The pain is indescribable’
# 109 VERIFICATION DAMAGES TO SCHOOLS
# 110 Humanitarian Gaza Strip
# 111 Humanitarian Situation Update #224 | Gaza Strip
# 112 PALESTINE One year of hostilities: impact on education in Gaza
# 113 Gaza humanitarian response update | 16-29 September 2024
# 114 Gaza Humanitarian 29 September 2024

# %% [markdown]
# # Save sources with metadata for all the extracted events in a given folder

# %% [markdown]
# This cell is to create new data sources with the metadata for the selected sources.
# The selected metadata are just the title and the url, it's easy to add more information in case.

# %%
input_folder_path = "/Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set"

output_folder_path = "/Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent-Metadata/Dev set"
# Loop through all files in the directory
for filename in os.listdir(input_folder_path)[::-1]:
    # Check if the file is a JSON file
    if filename.endswith(".json"):
        file_path = os.path.join(input_folder_path, filename)
        print(f"Processing file: {file_path}")
        
        # Load the JSON content
        with open(file_path, "r") as f:
            sources_dict = json.load(f)
            
           
        # Create DataFrame from the loaded JSON
        sources_df = pd.DataFrame([
            {"index": k, "content": v.split("\n content: ")[1], "title": v.split("\n content: ")[0].replace("title: ", "")} 
            for k, v in sources_dict.items()
        ])
        
        # Create an empty list to store the updated sources
        updated_sources_list = []

        for key, value in sources_dict.items():
            title = value.split("\n content: ")[0].replace("title: ", "").strip()
            content = value.split("\n content: ")[1].strip()
            
            
            # Find the row in filtered_data that matches both the title and content
            matching_row = full_data[(full_data['content']==content) | (full_data['title']==title)].drop_duplicates(subset='content')
            
            # If a match is found, extract the URL, otherwise set it to "No URL available"
            if not matching_row.empty:
                url = matching_row['url'].values[0]  # Get the URL from the matching row
            else:
                url = "No URL available"
            
            # Add the row to the updated_sources_list with the URL
            updated_sources_list.append({
                "row_number": key,
                "title": matching_row["title"].values[0],
                "content": f"title: {title} \n content: {content}",
                "url": url
            })

    # Convert the updated sources list back to a dictionary
        updated_sources_dict = {item["row_number"]: item for item in updated_sources_list}
            #print(updated_sources_dict)
            
    with open(f"{output_folder_path}/sources-metadata-{filename}", "w") as f:
        json.dump(updated_sources_dict, f, indent=4)
# Out:
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/Afghanistan_Afghanistan Floods-Week 21 2024.json
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/United Kingdom_UK riots-Week 32 2024.json
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/Ukraine_Ukraine-Week 23 2024.json
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/Israel_Israel-Hamas war-Week 19 2024.json
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/Sudan_Sudan conflict-Week 34 2024.json
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/Indonesia_Floods and volcanic activity in Indonesia-Week 20 2024.json
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/Bangladesh_Cyclone Remal-Week 21 2024.json
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/India_LandslideFloods-Week 31 2024.json
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/Nigeria_Flooding in Nigeria-Week 37 2024.json
# Processing file: /Users/decostanzi/Desktop/Project-ISI/SmartBook/SmartBook-Reports/Pipeline_DatasetDerya/Results/SourcesCountryEvent/Dev set/Haiti_Gang violence and humanitarian crisis in Haiti-Week 40 2024.json
